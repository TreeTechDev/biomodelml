# %% [markdown]
# # Comparing channels
#
# - R: sequential
# - G: complementary
# - B: not match at all

# %%
import ppscore
import pandas
import os
import numpy
from scipy.stats import spearmanr
from IPython.core.display import display, HTML
from ete3 import Tree
# Out:
# /tmp/ipykernel_9927/499083497.py:6: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
tree_path = "../../../data/trees"
channels = ("full", "gray_r", "gray_g", "gray_b", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin"]

# %%
def read_and_compare(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            try:
                df = pandas.read_csv(f"{path}/{file}", index_col=0)
                result_dict[basename] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
            except FileNotFoundError:
                pass
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Euclidean Distance from distance matrices

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          1.5868
# orthologs_myoglobin                                                2.0903
# orthologs_neuroglobin                                              5.5957
# orthologs_cytoglobin                                              10.5236
#
# index                      Universal Quality Index  \
# dataset
# orthologs_hemoglobin_beta                   0.9008
# orthologs_myoglobin                         0.9482
# orthologs_neuroglobin                       3.1412
# orthologs_cytoglobin                        6.0878
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
#
# index                      Deep Search with Annoy     full  \
# dataset
# orthologs_hemoglobin_beta                  4.8645   1.9025
# orthologs_myoglobin                        4.8090   2.0037
# orthologs_neuroglobin                      6.0855   5.9109
# orthologs_cytoglobin                      10.1226  11.1170
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
#
# index                      Local with Smith–Waterman   gray_r   gray_g  \
# dataset
# orthologs_hemoglobin_beta                     0.8937   1.8161   1.8564
# orthologs_myoglobin                           0.9044   1.8320   1.9685
# orthologs_neuroglobin                         1.1514   5.8736   5.9064
# orthologs_cytoglobin                          3.1095  11.0819  11.1145
#
# index                       gray_b  gray_mean
# dataset
# orthologs_hemoglobin_beta   2.0453     1.1396
# orthologs_myoglobin         2.2213     1.1520
# orthologs_neuroglobin       5.9644     1.7182
# orthologs_cytoglobin       11.1551     3.2222

# %%
def read_and_linear_correlate(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            try:
                df = pandas.read_csv(f"{path}/{file}", index_col=0)
                result_dict[basename] = round(spearmanr(control_df.values.flatten(), df.values.flatten())[0], 4)
            except FileNotFoundError:
                pass
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Linear Correlation from distance matrices

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_linear_correlate(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# /home/dmvieira/.virtualenvs/bioinfo2.0/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          0.9844
# orthologs_myoglobin                                                0.9688
# orthologs_neuroglobin                                              0.9747
# orthologs_cytoglobin                                               0.2268
#
# index                      Universal Quality Index  \
# dataset
# orthologs_hemoglobin_beta                   0.9984
# orthologs_myoglobin                         0.9988
# orthologs_neuroglobin                       0.9966
# orthologs_cytoglobin                        0.4723
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9999
# orthologs_myoglobin                              0.9999
# orthologs_neuroglobin                            0.9999
# orthologs_cytoglobin                             0.7775
#
# index                      Deep Search with Annoy    full  \
# dataset
# orthologs_hemoglobin_beta                  0.2257  0.9981
# orthologs_myoglobin                        0.3322  0.9985
# orthologs_neuroglobin                      0.1127  0.9900
# orthologs_cytoglobin                       0.2521  0.1597
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         1.0
# orthologs_myoglobin                               1.0
# orthologs_neuroglobin                             1.0
# orthologs_cytoglobin                              1.0
#
# index                      Local with Smith–Waterman  gray_r  gray_g  gray_b  \
# dataset
# orthologs_hemoglobin_beta                     0.9998  0.9977  0.9987  0.9928
# orthologs_myoglobin                           0.9998  0.9924  0.9985  0.9923
# orthologs_neuroglobin                         0.9992  0.9800  0.9890  0.9891
# orthologs_cytoglobin                          0.8623  0.1901  0.1764  0.1726
#
# index                      gray_mean
# dataset
# orthologs_hemoglobin_beta        NaN
# orthologs_myoglobin              NaN
# orthologs_neuroglobin            NaN
# orthologs_cytoglobin             NaN

# %%
def read_and_correlate(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            try:
                df = pandas.read_csv(f"{path}/{file}", index_col=0)
                result_dict[basename] = round(ppscore.score(
                    pandas.DataFrame({"x": control_df.values.flatten(), "y": df.values.flatten()}), "x", "y")["ppscore"], 4)
            except FileNotFoundError:
                pass
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Predictive Power Score from distance matrices

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_correlate(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          0.9216
# orthologs_myoglobin                                                0.9265
# orthologs_neuroglobin                                              0.9573
# orthologs_cytoglobin                                               0.7672
#
# index                      Universal Quality Index  \
# dataset
# orthologs_hemoglobin_beta                   0.9833
# orthologs_myoglobin                         0.9820
# orthologs_neuroglobin                       0.9701
# orthologs_cytoglobin                        0.7955
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9953
# orthologs_myoglobin                              0.9954
# orthologs_neuroglobin                            0.9876
# orthologs_cytoglobin                             0.8524
#
# index                      Deep Search with Annoy    full  \
# dataset
# orthologs_hemoglobin_beta                  0.4310  0.9794
# orthologs_myoglobin                        0.3510  0.9784
# orthologs_neuroglobin                      0.2930  0.9690
# orthologs_cytoglobin                       0.6626  0.7970
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                      0.9968
# orthologs_myoglobin                            0.9968
# orthologs_neuroglobin                          0.9964
# orthologs_cytoglobin                           0.9913
#
# index                      Local with Smith–Waterman  gray_r  gray_g  gray_b  \
# dataset
# orthologs_hemoglobin_beta                     0.9944  0.9836  0.9848  0.9501
# orthologs_myoglobin                           0.9925  0.9648  0.9729  0.9306
# orthologs_neuroglobin                         0.9897  0.9661  0.9672  0.9618
# orthologs_cytoglobin                          0.8584  0.7964  0.7974  0.7962
#
# index                      gray_mean
# dataset
# orthologs_hemoglobin_beta        0.0
# orthologs_myoglobin              0.0
# orthologs_neuroglobin            0.0
# orthologs_cytoglobin             0.0

# %%
def read_and_tree_compare(dataset, channel="full", control="Control with Clustal Omega"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_tree = Tree(f"{path}/{control}.nw", format=1)
    for file in os.listdir(path):
        if file.endswith(".nw"):
            basename = ".".join(file.split(".")[0:-1])
            try:
                tree = Tree(f"{path}/{file}", format=1)
                result = control_tree.compare(tree, unrooted=True)
                result_dict[basename] = round(result["norm_rf"], 4)
            except FileNotFoundError:
                pass
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Robinson-foulds distance from generated Trees

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0000
# orthologs_cytoglobin                             0.6667
#
# index                      Local with Smith–Waterman  Deep Search with Annoy  \
# dataset
# orthologs_hemoglobin_beta                        0.0                  1.0000
# orthologs_myoglobin                              0.0                  0.9167
# orthologs_neuroglobin                            0.0                  0.9167
# orthologs_cytoglobin                             0.5                  1.0000
#
# index                        full  \
# dataset
# orthologs_hemoglobin_beta  0.0000
# orthologs_myoglobin        0.0000
# orthologs_neuroglobin      0.0833
# orthologs_cytoglobin       0.9167
#
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          0.0000
# orthologs_myoglobin                                                0.0000
# orthologs_neuroglobin                                              0.1667
# orthologs_cytoglobin                                               0.9167
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
#
# index                      Universal Quality Index  gray_r  gray_g  gray_b  \
# dataset
# orthologs_hemoglobin_beta                   0.0000  0.0000  0.0000  0.1667
# orthologs_myoglobin                         0.0000  0.0833  0.0833  0.1667
# orthologs_neuroglobin                       0.0833  0.0833  0.0833  0.0833
# orthologs_cytoglobin                        0.9167  0.9167  0.9167  0.8333
#
# index                      gray_mean
# dataset
# orthologs_hemoglobin_beta        1.0
# orthologs_myoglobin              1.0
# orthologs_neuroglobin            1.0
# orthologs_cytoglobin             1.0

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare(dataset, channel, "Global with Needleman-Wunsch"))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                           0.0
# orthologs_myoglobin                                 0.0
# orthologs_neuroglobin                               0.0
# orthologs_cytoglobin                                0.0
#
# index                      Local with Smith–Waterman  Deep Search with Annoy  \
# dataset
# orthologs_hemoglobin_beta                       0.00                  1.0000
# orthologs_myoglobin                             0.00                  0.9167
# orthologs_neuroglobin                           0.00                  0.9167
# orthologs_cytoglobin                            0.25                  1.0000
#
# index                        full  \
# dataset
# orthologs_hemoglobin_beta  0.0000
# orthologs_myoglobin        0.0000
# orthologs_neuroglobin      0.0833
# orthologs_cytoglobin       0.6667
#
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          0.0000
# orthologs_myoglobin                                                0.0000
# orthologs_neuroglobin                                              0.1667
# orthologs_cytoglobin                                               0.6667
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                      0.0000
# orthologs_myoglobin                            0.0000
# orthologs_neuroglobin                          0.0000
# orthologs_cytoglobin                           0.6667
#
# index                      Universal Quality Index  gray_r  gray_g  gray_b  \
# dataset
# orthologs_hemoglobin_beta                   0.0000  0.0000  0.0000  0.1667
# orthologs_myoglobin                         0.0000  0.0833  0.0833  0.1667
# orthologs_neuroglobin                       0.0833  0.0833  0.0833  0.0833
# orthologs_cytoglobin                        0.5000  0.6667  0.6667  0.6667
#
# index                      gray_mean
# dataset
# orthologs_hemoglobin_beta        1.0
# orthologs_myoglobin              1.0
# orthologs_neuroglobin            1.0
# orthologs_cytoglobin             1.0

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare(dataset, channel, "Local with Smith–Waterman"))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                          0.00
# orthologs_myoglobin                                0.00
# orthologs_neuroglobin                              0.00
# orthologs_cytoglobin                               0.25
#
# index                      Local with Smith–Waterman  Deep Search with Annoy  \
# dataset
# orthologs_hemoglobin_beta                        0.0                  1.0000
# orthologs_myoglobin                              0.0                  0.9167
# orthologs_neuroglobin                            0.0                  0.9167
# orthologs_cytoglobin                             0.0                  1.0000
#
# index                        full  \
# dataset
# orthologs_hemoglobin_beta  0.0000
# orthologs_myoglobin        0.0000
# orthologs_neuroglobin      0.0833
# orthologs_cytoglobin       0.7500
#
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          0.0000
# orthologs_myoglobin                                                0.0000
# orthologs_neuroglobin                                              0.1667
# orthologs_cytoglobin                                               0.7500
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.5
#
# index                      Universal Quality Index  gray_r  gray_g  gray_b  \
# dataset
# orthologs_hemoglobin_beta                   0.0000  0.0000  0.0000  0.1667
# orthologs_myoglobin                         0.0000  0.0833  0.0833  0.1667
# orthologs_neuroglobin                       0.0833  0.0833  0.0833  0.0833
# orthologs_cytoglobin                        0.6667  0.7500  0.7500  0.6667
#
# index                      gray_mean
# dataset
# orthologs_hemoglobin_beta        1.0
# orthologs_myoglobin              1.0
# orthologs_neuroglobin            1.0
# orthologs_cytoglobin             1.0

# %%
def read_and_tree_compare_branches(dataset, channel="full"):
    result_dict = {}
    path = f"{tree_path}/{channel}/{dataset}"
    control_tree = Tree(f"{path}/Control with Clustal Omega.nw", format=1)
    for file in os.listdir(path):
        if file.endswith(".nw"):
            basename = ".".join(file.split(".")[0:-1])
            try:
                tree = Tree(f"{path}/{file}", format=1)
                result = control_tree.compare(tree, unrooted=True)
                result_dict[basename] = 1.0 - round(result["source_edges_in_ref"], 4)
            except FileNotFoundError:
                pass
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Compatibility branch score from generated Trees

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare_branches(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates(["index"]).set_index("index").T
# Out:
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0000
# orthologs_cytoglobin                             0.3077
#
# index                      Local with Smith–Waterman  Deep Search with Annoy  \
# dataset
# orthologs_hemoglobin_beta                     0.0000                  0.4615
# orthologs_myoglobin                           0.0000                  0.4231
# orthologs_neuroglobin                         0.0000                  0.4231
# orthologs_cytoglobin                          0.2308                  0.4615
#
# index                        full  \
# dataset
# orthologs_hemoglobin_beta  0.0000
# orthologs_myoglobin        0.0000
# orthologs_neuroglobin      0.0385
# orthologs_cytoglobin       0.4231
#
# index                      MultiScale Structural Similarity Index Measure  \
# dataset
# orthologs_hemoglobin_beta                                          0.0000
# orthologs_myoglobin                                                0.0000
# orthologs_neuroglobin                                              0.0769
# orthologs_cytoglobin                                               0.4231
#
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
#
# index                      Universal Quality Index  gray_r  gray_g  gray_b  \
# dataset
# orthologs_hemoglobin_beta                   0.0000  0.0000  0.0000  0.0769
# orthologs_myoglobin                         0.0000  0.0385  0.0385  0.0769
# orthologs_neuroglobin                       0.0385  0.0385  0.0385  0.0385
# orthologs_cytoglobin                        0.4231  0.4231  0.4231  0.3846
#
# index                      gray_mean
# dataset
# orthologs_hemoglobin_beta     0.4615
# orthologs_myoglobin           0.4615
# orthologs_neuroglobin         0.4615
# orthologs_cytoglobin          0.4615

# %%
def read_and_compare_channels(dataset):
    result_dict = {}
    dfs = {}
    for channel in channels:
        result_dict[channel] = {}
        path = f"{tree_path}/{channel}/{dataset}"
        dfs[channel] = pandas.read_csv(f"{path}/Structural Similarity Index Measure.csv", index_col=0)
    for channel in channels:
        control_df = dfs[channel]
        for c, df in dfs.items():
            result_dict[channel][c] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame.from_dict(result_dict, orient='index')
    result_df.index.name = "dataset"
    return result_df.style.background_gradient(axis=None, vmin=result_df.min().min(), vmax=result_df.max().max(), cmap="YlGnBu")

# %% [markdown]
# ## Features Euclidean distance from distance matrices

# %%
for dataset in datasets:
    try:
        correlations = read_and_compare_channels(dataset)
    except FileNotFoundError:
        continue
    else:
        display(HTML(f"<center><h3>{dataset}</h3></center>"))
        display(correlations)
# Out:
# <center><h3>orthologs_hemoglobin_beta</h3></center>
# <style type="text/css">
# #T_1fb47_row0_col0, #T_1fb47_row1_col1, #T_1fb47_row2_col2, #T_1fb47_row3_col3, #T_1fb47_row4_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_1fb47_row0_col1, #T_1fb47_row1_col0 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_1fb47_row0_col2, #T_1fb47_row2_col0 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_1fb47_row0_col3, #T_1fb47_row3_col0 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_1fb47_row0_col4, #T_1fb47_row4_col0 {
#   background-color: #12256d;
#   color: #f1f1f1;
# }
# #T_1fb47_row1_col2, #T_1fb47_row2_col1 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_1fb47_row1_col3, #T_1fb47_row3_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_1fb47_row1_col4, #T_1fb47_row4_col1 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_1fb47_row2_col3, #T_1fb47_row3_col2 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_1fb47_row2_col4, #T_1fb47_row4_col2 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_1fb47_row3_col4, #T_1fb47_row4_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1fb47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fb47_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_1fb47_level0_col1" class="col_heading level0 col1" >gray_r</th>
#       <th id="T_1fb47_level0_col2" class="col_heading level0 col2" >gray_g</th>
#       <th id="T_1fb47_level0_col3" class="col_heading level0 col3" >gray_b</th>
#       <th id="T_1fb47_level0_col4" class="col_heading level0 col4" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fb47_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_1fb47_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_1fb47_row0_col1" class="data row0 col1" >0.112100</td>
#       <td id="T_1fb47_row0_col2" class="data row0 col2" >0.087300</td>
#       <td id="T_1fb47_row0_col3" class="data row0 col3" >0.197300</td>
#       <td id="T_1fb47_row0_col4" class="data row0 col4" >3.039200</td>
#     </tr>
#     <tr>
#       <th id="T_1fb47_level0_row1" class="row_heading level0 row1" >gray_r</th>
#       <td id="T_1fb47_row1_col0" class="data row1 col0" >0.112100</td>
#       <td id="T_1fb47_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_1fb47_row1_col2" class="data row1 col2" >0.048600</td>
#       <td id="T_1fb47_row1_col3" class="data row1 col3" >0.308200</td>
#       <td id="T_1fb47_row1_col4" class="data row1 col4" >2.954200</td>
#     </tr>
#     <tr>
#       <th id="T_1fb47_level0_row2" class="row_heading level0 row2" >gray_g</th>
#       <td id="T_1fb47_row2_col0" class="data row2 col0" >0.087300</td>
#       <td id="T_1fb47_row2_col1" class="data row2 col1" >0.048600</td>
#       <td id="T_1fb47_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_1fb47_row2_col3" class="data row2 col3" >0.282800</td>
#       <td id="T_1fb47_row2_col4" class="data row2 col4" >2.994600</td>
#     </tr>
#     <tr>
#       <th id="T_1fb47_level0_row3" class="row_heading level0 row3" >gray_b</th>
#       <td id="T_1fb47_row3_col0" class="data row3 col0" >0.197300</td>
#       <td id="T_1fb47_row3_col1" class="data row3 col1" >0.308200</td>
#       <td id="T_1fb47_row3_col2" class="data row3 col2" >0.282800</td>
#       <td id="T_1fb47_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_1fb47_row3_col4" class="data row3 col4" >3.176500</td>
#     </tr>
#     <tr>
#       <th id="T_1fb47_level0_row4" class="row_heading level0 row4" >gray_mean</th>
#       <td id="T_1fb47_row4_col0" class="data row4 col0" >3.039200</td>
#       <td id="T_1fb47_row4_col1" class="data row4 col1" >2.954200</td>
#       <td id="T_1fb47_row4_col2" class="data row4 col2" >2.994600</td>
#       <td id="T_1fb47_row4_col3" class="data row4 col3" >3.176500</td>
#       <td id="T_1fb47_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <center><h3>orthologs_myoglobin</h3></center>
# <style type="text/css">
# #T_1d697_row0_col0, #T_1d697_row1_col1, #T_1d697_row2_col2, #T_1d697_row3_col3, #T_1d697_row4_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_1d697_row0_col1, #T_1d697_row1_col0 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_1d697_row0_col2, #T_1d697_row2_col0 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_1d697_row0_col3, #T_1d697_row3_col0 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_1d697_row0_col4, #T_1d697_row4_col0 {
#   background-color: #172976;
#   color: #f1f1f1;
# }
# #T_1d697_row1_col2, #T_1d697_row2_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_1d697_row1_col3, #T_1d697_row3_col1 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_1d697_row1_col4, #T_1d697_row4_col1 {
#   background-color: #22328f;
#   color: #f1f1f1;
# }
# #T_1d697_row2_col3, #T_1d697_row3_col2 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_1d697_row2_col4, #T_1d697_row4_col2 {
#   background-color: #192b7c;
#   color: #f1f1f1;
# }
# #T_1d697_row3_col4, #T_1d697_row4_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1d697">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d697_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_1d697_level0_col1" class="col_heading level0 col1" >gray_r</th>
#       <th id="T_1d697_level0_col2" class="col_heading level0 col2" >gray_g</th>
#       <th id="T_1d697_level0_col3" class="col_heading level0 col3" >gray_b</th>
#       <th id="T_1d697_level0_col4" class="col_heading level0 col4" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d697_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_1d697_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_1d697_row0_col1" class="data row0 col1" >0.200900</td>
#       <td id="T_1d697_row0_col2" class="data row0 col2" >0.081500</td>
#       <td id="T_1d697_row0_col3" class="data row0 col3" >0.253200</td>
#       <td id="T_1d697_row0_col4" class="data row0 col4" >3.154500</td>
#     </tr>
#     <tr>
#       <th id="T_1d697_level0_row1" class="row_heading level0 row1" >gray_r</th>
#       <td id="T_1d697_row1_col0" class="data row1 col0" >0.200900</td>
#       <td id="T_1d697_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_1d697_row1_col2" class="data row1 col2" >0.175900</td>
#       <td id="T_1d697_row1_col3" class="data row1 col3" >0.449700</td>
#       <td id="T_1d697_row1_col4" class="data row1 col4" >2.982300</td>
#     </tr>
#     <tr>
#       <th id="T_1d697_level0_row2" class="row_heading level0 row2" >gray_g</th>
#       <td id="T_1d697_row2_col0" class="data row2 col0" >0.081500</td>
#       <td id="T_1d697_row2_col1" class="data row2 col1" >0.175900</td>
#       <td id="T_1d697_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_1d697_row2_col3" class="data row2 col3" >0.316600</td>
#       <td id="T_1d697_row2_col4" class="data row2 col4" >3.118700</td>
#     </tr>
#     <tr>
#       <th id="T_1d697_level0_row3" class="row_heading level0 row3" >gray_b</th>
#       <td id="T_1d697_row3_col0" class="data row3 col0" >0.253200</td>
#       <td id="T_1d697_row3_col1" class="data row3 col1" >0.449700</td>
#       <td id="T_1d697_row3_col2" class="data row3 col2" >0.316600</td>
#       <td id="T_1d697_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_1d697_row3_col4" class="data row3 col4" >3.370400</td>
#     </tr>
#     <tr>
#       <th id="T_1d697_level0_row4" class="row_heading level0 row4" >gray_mean</th>
#       <td id="T_1d697_row4_col0" class="data row4 col0" >3.154500</td>
#       <td id="T_1d697_row4_col1" class="data row4 col1" >2.982300</td>
#       <td id="T_1d697_row4_col2" class="data row4 col2" >3.118700</td>
#       <td id="T_1d697_row4_col3" class="data row4 col3" >3.370400</td>
#       <td id="T_1d697_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <center><h3>orthologs_neuroglobin</h3></center>
# <style type="text/css">
# #T_b2dad_row0_col0, #T_b2dad_row1_col1, #T_b2dad_row2_col2, #T_b2dad_row3_col3, #T_b2dad_row4_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_b2dad_row0_col1, #T_b2dad_row1_col0 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_b2dad_row0_col2, #T_b2dad_row2_col0 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_b2dad_row0_col3, #T_b2dad_row3_col0 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_b2dad_row0_col4, #T_b2dad_row2_col4, #T_b2dad_row4_col0, #T_b2dad_row4_col2 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_b2dad_row1_col2, #T_b2dad_row2_col1 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_b2dad_row1_col3, #T_b2dad_row3_col1 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_b2dad_row1_col4, #T_b2dad_row4_col1 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_b2dad_row2_col3, #T_b2dad_row3_col2 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_b2dad_row3_col4, #T_b2dad_row4_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2dad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2dad_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_b2dad_level0_col1" class="col_heading level0 col1" >gray_r</th>
#       <th id="T_b2dad_level0_col2" class="col_heading level0 col2" >gray_g</th>
#       <th id="T_b2dad_level0_col3" class="col_heading level0 col3" >gray_b</th>
#       <th id="T_b2dad_level0_col4" class="col_heading level0 col4" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2dad_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_b2dad_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_b2dad_row0_col1" class="data row0 col1" >0.163400</td>
#       <td id="T_b2dad_row0_col2" class="data row0 col2" >0.137700</td>
#       <td id="T_b2dad_row0_col3" class="data row0 col3" >0.301200</td>
#       <td id="T_b2dad_row0_col4" class="data row0 col4" >7.471600</td>
#     </tr>
#     <tr>
#       <th id="T_b2dad_level0_row1" class="row_heading level0 row1" >gray_r</th>
#       <td id="T_b2dad_row1_col0" class="data row1 col0" >0.163400</td>
#       <td id="T_b2dad_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_b2dad_row1_col2" class="data row1 col2" >0.044500</td>
#       <td id="T_b2dad_row1_col3" class="data row1 col3" >0.463900</td>
#       <td id="T_b2dad_row1_col4" class="data row1 col4" >7.427100</td>
#     </tr>
#     <tr>
#       <th id="T_b2dad_level0_row2" class="row_heading level0 row2" >gray_g</th>
#       <td id="T_b2dad_row2_col0" class="data row2 col0" >0.137700</td>
#       <td id="T_b2dad_row2_col1" class="data row2 col1" >0.044500</td>
#       <td id="T_b2dad_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_b2dad_row2_col3" class="data row2 col3" >0.438100</td>
#       <td id="T_b2dad_row2_col4" class="data row2 col4" >7.461700</td>
#     </tr>
#     <tr>
#       <th id="T_b2dad_level0_row3" class="row_heading level0 row3" >gray_b</th>
#       <td id="T_b2dad_row3_col0" class="data row3 col0" >0.301200</td>
#       <td id="T_b2dad_row3_col1" class="data row3 col1" >0.463900</td>
#       <td id="T_b2dad_row3_col2" class="data row3 col2" >0.438100</td>
#       <td id="T_b2dad_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_b2dad_row3_col4" class="data row3 col4" >7.535200</td>
#     </tr>
#     <tr>
#       <th id="T_b2dad_level0_row4" class="row_heading level0 row4" >gray_mean</th>
#       <td id="T_b2dad_row4_col0" class="data row4 col0" >7.471600</td>
#       <td id="T_b2dad_row4_col1" class="data row4 col1" >7.427100</td>
#       <td id="T_b2dad_row4_col2" class="data row4 col2" >7.461700</td>
#       <td id="T_b2dad_row4_col3" class="data row4 col3" >7.535200</td>
#       <td id="T_b2dad_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# <center><h3>orthologs_cytoglobin</h3></center>
# <style type="text/css">
# #T_e79a1_row0_col0, #T_e79a1_row0_col2, #T_e79a1_row1_col1, #T_e79a1_row1_col2, #T_e79a1_row2_col0, #T_e79a1_row2_col1, #T_e79a1_row2_col2, #T_e79a1_row3_col3, #T_e79a1_row4_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e79a1_row0_col1, #T_e79a1_row0_col3, #T_e79a1_row1_col0, #T_e79a1_row3_col0 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_e79a1_row0_col4, #T_e79a1_row2_col4, #T_e79a1_row3_col4, #T_e79a1_row4_col0, #T_e79a1_row4_col2, #T_e79a1_row4_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_e79a1_row1_col3, #T_e79a1_row2_col3, #T_e79a1_row3_col1, #T_e79a1_row3_col2 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_e79a1_row1_col4, #T_e79a1_row4_col1 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e79a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e79a1_level0_col0" class="col_heading level0 col0" >full</th>
#       <th id="T_e79a1_level0_col1" class="col_heading level0 col1" >gray_r</th>
#       <th id="T_e79a1_level0_col2" class="col_heading level0 col2" >gray_g</th>
#       <th id="T_e79a1_level0_col3" class="col_heading level0 col3" >gray_b</th>
#       <th id="T_e79a1_level0_col4" class="col_heading level0 col4" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e79a1_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_e79a1_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_e79a1_row0_col1" class="data row0 col1" >0.054800</td>
#       <td id="T_e79a1_row0_col2" class="data row0 col2" >0.039800</td>
#       <td id="T_e79a1_row0_col3" class="data row0 col3" >0.082900</td>
#       <td id="T_e79a1_row0_col4" class="data row0 col4" >13.918200</td>
#     </tr>
#     <tr>
#       <th id="T_e79a1_level0_row1" class="row_heading level0 row1" >gray_r</th>
#       <td id="T_e79a1_row1_col0" class="data row1 col0" >0.054800</td>
#       <td id="T_e79a1_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_e79a1_row1_col2" class="data row1 col2" >0.048600</td>
#       <td id="T_e79a1_row1_col3" class="data row1 col3" >0.134700</td>
#       <td id="T_e79a1_row1_col4" class="data row1 col4" >13.882600</td>
#     </tr>
#     <tr>
#       <th id="T_e79a1_level0_row2" class="row_heading level0 row2" >gray_g</th>
#       <td id="T_e79a1_row2_col0" class="data row2 col0" >0.039800</td>
#       <td id="T_e79a1_row2_col1" class="data row2 col1" >0.048600</td>
#       <td id="T_e79a1_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_e79a1_row2_col3" class="data row2 col3" >0.117800</td>
#       <td id="T_e79a1_row2_col4" class="data row2 col4" >13.915300</td>
#     </tr>
#     <tr>
#       <th id="T_e79a1_level0_row3" class="row_heading level0 row3" >gray_b</th>
#       <td id="T_e79a1_row3_col0" class="data row3 col0" >0.082900</td>
#       <td id="T_e79a1_row3_col1" class="data row3 col1" >0.134700</td>
#       <td id="T_e79a1_row3_col2" class="data row3 col2" >0.117800</td>
#       <td id="T_e79a1_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_e79a1_row3_col4" class="data row3 col4" >13.957000</td>
#     </tr>
#     <tr>
#       <th id="T_e79a1_level0_row4" class="row_heading level0 row4" >gray_mean</th>
#       <td id="T_e79a1_row4_col0" class="data row4 col0" >13.918200</td>
#       <td id="T_e79a1_row4_col1" class="data row4 col1" >13.882600</td>
#       <td id="T_e79a1_row4_col2" class="data row4 col2" >13.915300</td>
#       <td id="T_e79a1_row4_col3" class="data row4 col3" >13.957000</td>
#       <td id="T_e79a1_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
