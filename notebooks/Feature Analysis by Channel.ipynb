# %%
import pandas
import os
import numpy
from IPython.core.display import display, HTML

# %%
def read_and_compare(dataset, channel="full"):
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]

# %%
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.drop_duplicates().T
# Out:
#                            Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
#                            Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
#                            Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.1542  0.8342  0.7896
# orthologs_myoglobin                           0.9044  0.0954  0.8046  0.7975
# orthologs_neuroglobin                         1.1514  1.2176  0.9789  0.9323
# orthologs_cytoglobin                          3.1095  2.7743  1.8149  1.7804
# orthologs_androglobin                         2.9601  4.0221  1.0736  1.0347
#
#                              blue  red_green  red_blue  green_blue
# dataset
# orthologs_hemoglobin_beta  0.8000     0.4849    0.4957      0.4511
# orthologs_myoglobin        0.7811     0.4510    0.4347      0.4279
# orthologs_neuroglobin      0.9554     0.6618    0.6385      0.6520
# orthologs_cytoglobin       1.7816     1.5191    1.5174      1.5304
# orthologs_androglobin      1.0623     2.4228    2.4578      2.4023

# %%
def read_and_compare_channels(dataset):
    result_dict = {}
    dfs = {}
    for channel in channels:
        result_dict[channel] = {}
        path = f"../data/trees/{channel}/{dataset}"
        dfs[channel] = pandas.read_csv(f"{path}/MultiScale Structural Similarity Index Measure.csv", index_col=0)
    for channel in channels:
        control_df = dfs[channel]
        for c, df in dfs.items():
            result_dict[channel][c] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame.from_dict(result_dict, orient='index')
    result_df.index.name = "dataset"
    return result_df

# %%
for dataset in datasets:
    display(HTML(f"<center><h3>{dataset}</h3></center>"))
    display(read_and_compare_channels(dataset))
# Out:
# <center><h3>orthologs_hemoglobin_beta</h3></center>
#               full     red   green    blue  red_green  red_blue  green_blue
# dataset
# full        0.0000  0.6914  0.6469  0.6569     0.3408    0.3508      0.3064
# red         0.6914  0.0000  0.0479  0.0384     0.3508    0.3408      0.3857
# green       0.6469  0.0479  0.0000  0.0188     0.3064    0.2968      0.3408
# blue        0.6569  0.0384  0.0188  0.0000     0.3168    0.3064      0.3508
# red_green   0.3408  0.3508  0.3064  0.3168     0.0000    0.0188      0.0384
# red_blue    0.3508  0.3408  0.2968  0.3064     0.0188    0.0000      0.0479
# green_blue  0.3064  0.3857  0.3408  0.3508     0.0384    0.0479      0.0000
# <center><h3>orthologs_myoglobin</h3></center>
#               full     red   green    blue  red_green  red_blue  green_blue
# dataset
# full        0.0000  0.7273  0.7197  0.7035     0.3718    0.3558      0.3480
# red         0.7273  0.0000  0.0237  0.0267     0.3558    0.3718      0.3798
# green       0.7197  0.0237  0.0000  0.0285     0.3480    0.3653      0.3718
# blue        0.7035  0.0267  0.0285  0.0000     0.3323    0.3480      0.3558
# red_green   0.3718  0.3558  0.3480  0.3323     0.0000    0.0285      0.0267
# red_blue    0.3558  0.3718  0.3653  0.3480     0.0285    0.0000      0.0237
# green_blue  0.3480  0.3798  0.3718  0.3558     0.0267    0.0237      0.0000
# <center><h3>orthologs_neuroglobin</h3></center>
#               full     red   green    blue  red_green  red_blue  green_blue
# dataset
# full        0.0000  1.7868  1.7258  1.7690     0.8719    0.9150      0.8540
# red         1.7868  0.0000  0.0620  0.0270     0.9150    0.8719      0.9330
# green       1.7258  0.0620  0.0000  0.0476     0.8540    0.8109      0.8719
# blue        1.7690  0.0270  0.0476  0.0000     0.8975    0.8540      0.9150
# red_green   0.8719  0.9150  0.8540  0.8975     0.0000    0.0476      0.0270
# red_blue    0.9150  0.8719  0.8109  0.8540     0.0476    0.0000      0.0620
# green_blue  0.8540  0.9330  0.8719  0.9150     0.0270    0.0620      0.0000
# <center><h3>orthologs_cytoglobin</h3></center>
#               full     red   green    blue  red_green  red_blue  green_blue
# dataset
# full        0.0000  3.5723  3.5267  3.5294     1.7849    1.7875      1.7421
# red         3.5723  0.0000  0.0605  0.0616     1.7875    1.7849      1.8311
# green       3.5267  0.0605  0.0000  0.0217     1.7421    1.7395      1.7849
# blue        3.5294  0.0616  0.0217  0.0000     1.7450    1.7421      1.7875
# red_green   1.7849  1.7875  1.7421  1.7450     0.0000    0.0217      0.0616
# red_blue    1.7875  1.7849  1.7395  1.7421     0.0217    0.0000      0.0605
# green_blue  1.7421  1.8311  1.7849  1.7875     0.0616    0.0605      0.0000
# <center><h3>orthologs_androglobin</h3></center>
#               full     red   green    blue  red_green  red_blue  green_blue
# dataset
# full        0.0000  3.2925  3.3489  3.3153     1.6630    1.6295      1.6859
# red         3.2925  0.0000  0.0593  0.0262     1.6295    1.6630      1.6067
# green       3.3489  0.0593  0.0000  0.0359     1.6859    1.7195      1.6630
# blue        3.3153  0.0262  0.0359  0.0000     1.6523    1.6859      1.6295
# red_green   1.6630  1.6295  1.6859  1.6523     0.0000    0.0359      0.0262
# red_blue    1.6295  1.6630  1.7195  1.6859     0.0359    0.0000      0.0593
# green_blue  1.6859  1.6067  1.6630  1.6295     0.0262    0.0593      0.0000
