# %%
import pandas
import os
import numpy
from minepy import MINE
from IPython.core.display import display, HTML

# %%
def read_and_correlate(dataset, channel="full"):
    corr = MINE()
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            corr.compute_score(control_df.values.flatten(), df.values.flatten())
            result_dict[basename] = round(1 - corr.mic(), 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_correlate(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.drop_duplicates().T
# Out:
#                            Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                      0.0000
# orthologs_myoglobin                            0.0000
# orthologs_neuroglobin                          0.0004
# orthologs_cytoglobin                           0.0000
# orthologs_androglobin                          0.0000
#
#                            Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0004
# orthologs_cytoglobin                             0.0834
# orthologs_androglobin                            0.0537
#
#                            Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.0000  0.0000  0.0000  0.0000
# orthologs_myoglobin                           0.0000  0.0000  0.0000  0.0000
# orthologs_neuroglobin                         0.0004  0.0007  0.0007  0.0007
# orthologs_cytoglobin                          0.1259  0.4456  0.4088  0.3320
# orthologs_androglobin                         0.0000  0.2312  0.3447  0.3843
#
#                              blue  red_green  red_blue  green_blue  gray_r  \
# dataset
# orthologs_hemoglobin_beta  0.0000     0.0000    0.0000      0.0000  0.0000
# orthologs_myoglobin        0.0000     0.0000    0.0000      0.0000  0.0000
# orthologs_neuroglobin      0.0004     0.0116    0.0004      0.0004  0.0007
# orthologs_cytoglobin       0.4208     0.3754    0.4484      0.4310  0.4088
# orthologs_androglobin      0.3074     0.3220    0.3203      0.3510  0.3003
#
#                            gray_g  gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  0.0000  0.0000    0.0000     0.0000
# orthologs_myoglobin        0.0000  0.0000    0.0000     0.0000
# orthologs_neuroglobin      0.0004  0.0004    0.0007     0.0004
# orthologs_cytoglobin       0.4223  0.5115    0.4526     0.4970
# orthologs_androglobin      0.1864  0.3457    0.4067     0.2662

# %%
def read_and_compare(dataset, channel="full"):
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.drop_duplicates().T
# Out:
#                            Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
#                            Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
#                            Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.1542  0.8342  0.7896
# orthologs_myoglobin                           0.9044  0.0954  0.8046  0.7975
# orthologs_neuroglobin                         1.1514  1.2176  0.9789  0.9323
# orthologs_cytoglobin                          3.1095  2.7743  1.8149  1.7804
# orthologs_androglobin                         2.9601  4.0221  1.0736  1.0347
#
#                              blue  red_green  red_blue  green_blue  gray_r  \
# dataset
# orthologs_hemoglobin_beta  0.8000     0.4849    0.4957      0.4511  0.2308
# orthologs_myoglobin        0.7811     0.4510    0.4347      0.4279  0.1200
# orthologs_neuroglobin      0.9554     0.6618    0.6385      0.6520  1.1599
# orthologs_cytoglobin       1.7816     1.5191    1.5174      1.5304  2.7064
# orthologs_androglobin      1.0623     2.4228    2.4578      2.4023  4.1007
#
#                            gray_g  gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  1.0531  0.8252    0.3888     0.0754
# orthologs_myoglobin        1.0186  1.1060    0.5494     0.1964
# orthologs_neuroglobin      3.6185  3.2697    1.8501     1.1943
# orthologs_cytoglobin       7.4543  5.9601    4.0279     2.7103
# orthologs_androglobin      5.5073  4.4642    5.6728     3.7744

# %%
channels = ("full", "red", "green", "blue")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.drop_duplicates().T
# Out:
#                            Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
#                            Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
#                            Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.1542  0.8342  0.7896
# orthologs_myoglobin                           0.9044  0.0954  0.8046  0.7975
# orthologs_neuroglobin                         1.1514  1.2176  0.9789  0.9323
# orthologs_cytoglobin                          3.1095  2.7743  1.8149  1.7804
# orthologs_androglobin                         2.9601  4.0221  1.0736  1.0347
#
#                              blue
# dataset
# orthologs_hemoglobin_beta  0.8000
# orthologs_myoglobin        0.7811
# orthologs_neuroglobin      0.9554
# orthologs_cytoglobin       1.7816
# orthologs_androglobin      1.0623

# %%
channels = ("full", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.drop_duplicates().T
# Out:
#                            Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
#                            Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
#                            Local with Smith–Waterman    full  gray_r  gray_g  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.1542  0.2308  1.0531
# orthologs_myoglobin                           0.9044  0.0954  0.1200  1.0186
# orthologs_neuroglobin                         1.1514  1.2176  1.1599  3.6185
# orthologs_cytoglobin                          3.1095  2.7743  2.7064  7.4543
# orthologs_androglobin                         2.9601  4.0221  4.1007  5.5073
#
#                            gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  0.8252    0.3888     0.0754
# orthologs_myoglobin        1.1060    0.5494     0.1964
# orthologs_neuroglobin      3.2697    1.8501     1.1943
# orthologs_cytoglobin       5.9601    4.0279     2.7103
# orthologs_androglobin      4.4642    5.6728     3.7744

# %%
channels = ("full", "red_green", "red_blue", "green_blue")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.drop_duplicates().T
# Out:
#                            Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
#                            Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
#                            Local with Smith–Waterman    full  red_green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.1542     0.4849
# orthologs_myoglobin                           0.9044  0.0954     0.4510
# orthologs_neuroglobin                         1.1514  1.2176     0.6618
# orthologs_cytoglobin                          3.1095  2.7743     1.5191
# orthologs_androglobin                         2.9601  4.0221     2.4228
#
#                            red_blue  green_blue
# dataset
# orthologs_hemoglobin_beta    0.4957      0.4511
# orthologs_myoglobin          0.4347      0.4279
# orthologs_neuroglobin        0.6385      0.6520
# orthologs_cytoglobin         1.5174      1.5304
# orthologs_androglobin        2.4578      2.4023

# %%
def read_and_compare_channels(dataset):
    result_dict = {}
    dfs = {}
    channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
    for channel in channels:
        result_dict[channel] = {}
        path = f"../data/trees/{channel}/{dataset}"
        dfs[channel] = pandas.read_csv(f"{path}/MultiScale Structural Similarity Index Measure.csv", index_col=0)
    for channel in channels:
        control_df = dfs[channel]
        for c, df in dfs.items():
            result_dict[channel][c] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame.from_dict(result_dict, orient='index')
    result_df.index.name = "dataset"
    return result_df.style.background_gradient(axis=None, vmin=result_df.min().min(), vmax=result_df.max().max(), cmap="YlGnBu")

# %%
for dataset in datasets:
    display(HTML(f"<center><h3>{dataset}</h3></center>"))
    display(read_and_compare_channels(dataset))
# Out:
# <center><h3>orthologs_hemoglobin_beta</h3></center>
# <style type="text/css">
# #T_e6939_row0_col0, #T_e6939_row1_col1, #T_e6939_row2_col2, #T_e6939_row3_col3, #T_e6939_row4_col4, #T_e6939_row5_col5, #T_e6939_row6_col6, #T_e6939_row7_col7, #T_e6939_row8_col8, #T_e6939_row9_col9, #T_e6939_row10_col10, #T_e6939_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_e6939_row0_col1, #T_e6939_row1_col0 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_e6939_row0_col2, #T_e6939_row2_col0 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_e6939_row0_col3, #T_e6939_row3_col0 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_e6939_row0_col4, #T_e6939_row1_col5, #T_e6939_row2_col6, #T_e6939_row4_col0, #T_e6939_row5_col1, #T_e6939_row6_col2, #T_e6939_row8_col9, #T_e6939_row9_col8 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_e6939_row0_col5, #T_e6939_row1_col4, #T_e6939_row3_col6, #T_e6939_row4_col1, #T_e6939_row5_col0, #T_e6939_row6_col3 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_e6939_row0_col6, #T_e6939_row2_col4, #T_e6939_row3_col5, #T_e6939_row4_col2, #T_e6939_row5_col3, #T_e6939_row6_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_e6939_row0_col7, #T_e6939_row7_col0 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_e6939_row0_col8, #T_e6939_row8_col0 {
#   background-color: #1d8dbe;
#   color: #f1f1f1;
# }
# #T_e6939_row0_col9, #T_e6939_row9_col0 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_e6939_row0_col10, #T_e6939_row10_col0 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_e6939_row0_col11, #T_e6939_row11_col0 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_e6939_row1_col2, #T_e6939_row2_col1, #T_e6939_row5_col6, #T_e6939_row6_col5 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_e6939_row1_col3, #T_e6939_row3_col1, #T_e6939_row4_col6, #T_e6939_row6_col4 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_e6939_row1_col6, #T_e6939_row6_col1 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_e6939_row1_col7, #T_e6939_row7_col1 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_e6939_row1_col8, #T_e6939_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_e6939_row1_col9, #T_e6939_row9_col1 {
#   background-color: #253595;
#   color: #f1f1f1;
# }
# #T_e6939_row1_col10, #T_e6939_row10_col1 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_e6939_row1_col11, #T_e6939_row11_col1 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_e6939_row2_col3, #T_e6939_row3_col2, #T_e6939_row4_col5, #T_e6939_row5_col4 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_e6939_row2_col5, #T_e6939_row5_col2 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_e6939_row2_col7, #T_e6939_row7_col2 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_e6939_row2_col8, #T_e6939_row8_col2 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_e6939_row2_col9, #T_e6939_row9_col2 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_e6939_row2_col10, #T_e6939_row10_col2 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_e6939_row2_col11, #T_e6939_row11_col2 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_e6939_row3_col4, #T_e6939_row4_col3 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_e6939_row3_col7, #T_e6939_row7_col3 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_e6939_row3_col8, #T_e6939_row8_col3 {
#   background-color: #0c2060;
#   color: #f1f1f1;
# }
# #T_e6939_row3_col9, #T_e6939_row9_col3 {
#   background-color: #243c98;
#   color: #f1f1f1;
# }
# #T_e6939_row3_col10, #T_e6939_row10_col3 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
# }
# #T_e6939_row3_col11, #T_e6939_row11_col3 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_e6939_row4_col7, #T_e6939_row7_col4 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_e6939_row4_col8, #T_e6939_row8_col4 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_e6939_row4_col9, #T_e6939_row9_col4 {
#   background-color: #1f78b4;
#   color: #f1f1f1;
# }
# #T_e6939_row4_col10, #T_e6939_row10_col4 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_e6939_row4_col11, #T_e6939_row9_col10, #T_e6939_row10_col9, #T_e6939_row11_col4 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_e6939_row5_col7, #T_e6939_row7_col5 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_e6939_row5_col8, #T_e6939_row8_col5 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_e6939_row5_col9, #T_e6939_row9_col5 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_e6939_row5_col10, #T_e6939_row10_col5 {
#   background-color: #53bdc1;
#   color: #000000;
# }
# #T_e6939_row5_col11, #T_e6939_row11_col5 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_e6939_row6_col7, #T_e6939_row7_col6 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_e6939_row6_col8, #T_e6939_row8_col6 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_e6939_row6_col9, #T_e6939_row9_col6 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_e6939_row6_col10, #T_e6939_row10_col6 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_e6939_row6_col11, #T_e6939_row11_col6 {
#   background-color: #ceecb3;
#   color: #000000;
# }
# #T_e6939_row7_col8, #T_e6939_row8_col7 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_e6939_row7_col9, #T_e6939_row9_col7 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_e6939_row7_col10, #T_e6939_row10_col7 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_e6939_row7_col11, #T_e6939_row11_col7 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_e6939_row8_col10, #T_e6939_row10_col8 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_e6939_row8_col11, #T_e6939_row11_col8 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_e6939_row9_col11, #T_e6939_row11_col9 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_e6939_row10_col11, #T_e6939_row11_col10 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# </style>
# <table id="T_e6939_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6939_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_e6939_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_e6939_row0_col1" class="data row0 col1" >0.691400</td>
#       <td id="T_e6939_row0_col2" class="data row0 col2" >0.646900</td>
#       <td id="T_e6939_row0_col3" class="data row0 col3" >0.656900</td>
#       <td id="T_e6939_row0_col4" class="data row0 col4" >0.340800</td>
#       <td id="T_e6939_row0_col5" class="data row0 col5" >0.350800</td>
#       <td id="T_e6939_row0_col6" class="data row0 col6" >0.306400</td>
#       <td id="T_e6939_row0_col7" class="data row0 col7" >0.084800</td>
#       <td id="T_e6939_row0_col8" class="data row0 col8" >1.191100</td>
#       <td id="T_e6939_row0_col9" class="data row0 col9" >0.954300</td>
#       <td id="T_e6939_row0_col10" class="data row0 col10" >0.519700</td>
#       <td
# <center><h3>orthologs_myoglobin</h3></center>
# <style type="text/css">
# #T_223f1_row0_col0, #T_223f1_row1_col1, #T_223f1_row2_col2, #T_223f1_row3_col3, #T_223f1_row4_col4, #T_223f1_row5_col5, #T_223f1_row6_col6, #T_223f1_row7_col7, #T_223f1_row8_col8, #T_223f1_row9_col9, #T_223f1_row10_col10, #T_223f1_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_223f1_row0_col1, #T_223f1_row1_col0 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_223f1_row0_col2, #T_223f1_row2_col0 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_223f1_row0_col3, #T_223f1_row3_col0 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_223f1_row0_col4, #T_223f1_row1_col5, #T_223f1_row2_col6, #T_223f1_row4_col0, #T_223f1_row5_col1, #T_223f1_row6_col2, #T_223f1_row10_col11, #T_223f1_row11_col10 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_223f1_row0_col5, #T_223f1_row1_col4, #T_223f1_row3_col6, #T_223f1_row4_col1, #T_223f1_row5_col0, #T_223f1_row6_col3 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_223f1_row0_col6, #T_223f1_row2_col4, #T_223f1_row3_col5, #T_223f1_row4_col2, #T_223f1_row4_col7, #T_223f1_row5_col3, #T_223f1_row6_col0, #T_223f1_row7_col4 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_223f1_row0_col7, #T_223f1_row7_col0 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_223f1_row0_col8, #T_223f1_row8_col0 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_223f1_row0_col9, #T_223f1_row9_col0 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_223f1_row0_col10, #T_223f1_row10_col0 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_223f1_row0_col11, #T_223f1_row11_col0 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_223f1_row1_col2, #T_223f1_row1_col3, #T_223f1_row2_col1, #T_223f1_row2_col3, #T_223f1_row3_col1, #T_223f1_row3_col2, #T_223f1_row4_col5, #T_223f1_row4_col6, #T_223f1_row5_col4, #T_223f1_row5_col6, #T_223f1_row6_col4, #T_223f1_row6_col5 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_223f1_row1_col6, #T_223f1_row6_col1 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_223f1_row1_col7, #T_223f1_row7_col1 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_223f1_row1_col8, #T_223f1_row8_col1 {
#   background-color: #13266f;
#   color: #f1f1f1;
# }
# #T_223f1_row1_col9, #T_223f1_row9_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_223f1_row1_col10, #T_223f1_row10_col1 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_223f1_row1_col11, #T_223f1_row11_col1 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_223f1_row2_col5, #T_223f1_row5_col2 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_223f1_row2_col7, #T_223f1_row7_col2 {
#   background-color: #87d0ba;
#   color: #000000;
# }
# #T_223f1_row2_col8, #T_223f1_row8_col2 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_223f1_row2_col9, #T_223f1_row9_col2 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_223f1_row2_col10, #T_223f1_row10_col2 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# #T_223f1_row2_col11, #T_223f1_row5_col10, #T_223f1_row10_col5, #T_223f1_row11_col2 {
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# #T_223f1_row3_col4, #T_223f1_row4_col3 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_223f1_row3_col7, #T_223f1_row7_col3 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_223f1_row3_col8, #T_223f1_row8_col3 {
#   background-color: #162874;
#   color: #f1f1f1;
# }
# #T_223f1_row3_col9, #T_223f1_row9_col3 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_223f1_row3_col10, #T_223f1_row10_col3 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_223f1_row3_col11, #T_223f1_row11_col3 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_223f1_row4_col8, #T_223f1_row8_col4 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_223f1_row4_col9, #T_223f1_row9_col4 {
#   background-color: #24489d;
#   color: #f1f1f1;
# }
# #T_223f1_row4_col10, #T_223f1_row10_col4 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_223f1_row4_col11, #T_223f1_row11_col4 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_223f1_row5_col7, #T_223f1_row7_col5 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_223f1_row5_col8, #T_223f1_row8_col5 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_223f1_row5_col9, #T_223f1_row9_col5 {
#   background-color: #234b9f;
#   color: #f1f1f1;
# }
# #T_223f1_row5_col11, #T_223f1_row11_col5 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_223f1_row6_col7, #T_223f1_row7_col6 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_223f1_row6_col8, #T_223f1_row8_col6 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_223f1_row6_col9, #T_223f1_row9_col6 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_223f1_row6_col10, #T_223f1_row10_col6 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_223f1_row6_col11, #T_223f1_row11_col6 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_223f1_row7_col8, #T_223f1_row8_col7 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_223f1_row7_col9, #T_223f1_row9_col7 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_223f1_row7_col10, #T_223f1_row10_col7 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_223f1_row7_col11, #T_223f1_row11_col7 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_223f1_row8_col9, #T_223f1_row9_col8 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_223f1_row8_col10, #T_223f1_row10_col8 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_223f1_row8_col11, #T_223f1_row11_col8 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_223f1_row9_col10, #T_223f1_row10_col9 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_223f1_row9_col11, #T_223f1_row11_col9 {
#   background-color: #46b8c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_223f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_223f1_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_223f1_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_223f1_row0_col1" class="data row0 col1" >0.727300</td>
#       <td id="T_223f1_row0_col2" class="data row0 col2" >0.719700</td>
#       <td id="T_223f1_row0_col3" class="data row0 col3" >0.703500</td>
#       <td id="T_223f1_row0_col4" class="data row0 col4" >0.371800</td>
#       <td id="T_223f1_row0_col5" class="data row0 col5" >0.355800</td>
#       <td id="T_223f1_row0_col6" class="data row0 col6" >0.348000</td>
#       <td id="T_223f1_row0_col7" class="data row0 col7" >0.041800</td>
#       <td id="T_223f1_row0_col8" class="data row0 col8" >1.088000</td>
#       <td id="T_223f1_row0_col9" class="data row0 col9" >1.176600</td>
#       <td id="T_223f1_row0_col10" class="data row0 col10" >0.622900</td>
#       <td id="T_223f1_row0_col11" class="data row0 col11" >0.259700</td>
#     </tr>
#     <tr>
#       <th id="T_223f1_level0_row1" class="row_heading level0 row1" >
# <center><h3>orthologs_neuroglobin</h3></center>
# <style type="text/css">
# #T_bc0e6_row0_col0, #T_bc0e6_row1_col1, #T_bc0e6_row2_col2, #T_bc0e6_row3_col3, #T_bc0e6_row4_col4, #T_bc0e6_row5_col5, #T_bc0e6_row6_col6, #T_bc0e6_row7_col7, #T_bc0e6_row8_col8, #T_bc0e6_row9_col9, #T_bc0e6_row10_col10, #T_bc0e6_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_bc0e6_row0_col1, #T_bc0e6_row1_col0 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_bc0e6_row0_col2, #T_bc0e6_row2_col0 {
#   background-color: #71c8bd;
#   color: #000000;
# }
# #T_bc0e6_row0_col3, #T_bc0e6_row3_col0 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_bc0e6_row0_col4, #T_bc0e6_row1_col5, #T_bc0e6_row2_col6, #T_bc0e6_row4_col0, #T_bc0e6_row5_col1, #T_bc0e6_row6_col2 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_bc0e6_row0_col5, #T_bc0e6_row1_col4, #T_bc0e6_row3_col6, #T_bc0e6_row4_col1, #T_bc0e6_row5_col0, #T_bc0e6_row6_col3 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_bc0e6_row0_col6, #T_bc0e6_row2_col4, #T_bc0e6_row3_col5, #T_bc0e6_row4_col2, #T_bc0e6_row5_col3, #T_bc0e6_row6_col0 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_bc0e6_row0_col7, #T_bc0e6_row7_col0 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_bc0e6_row0_col8, #T_bc0e6_row1_col10, #T_bc0e6_row8_col0, #T_bc0e6_row10_col1 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_bc0e6_row0_col9, #T_bc0e6_row9_col0 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_bc0e6_row0_col10, #T_bc0e6_row10_col0 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_bc0e6_row0_col11, #T_bc0e6_row11_col0 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_bc0e6_row1_col2, #T_bc0e6_row2_col1, #T_bc0e6_row5_col6, #T_bc0e6_row6_col5 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_bc0e6_row1_col3, #T_bc0e6_row3_col1, #T_bc0e6_row4_col6, #T_bc0e6_row6_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_bc0e6_row1_col6, #T_bc0e6_row6_col1, #T_bc0e6_row6_col11, #T_bc0e6_row11_col6 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_bc0e6_row1_col7, #T_bc0e6_row7_col1 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_bc0e6_row1_col8, #T_bc0e6_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_bc0e6_row1_col9, #T_bc0e6_row9_col1 {
#   background-color: #172976;
#   color: #f1f1f1;
# }
# #T_bc0e6_row1_col11, #T_bc0e6_row11_col1 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_bc0e6_row2_col3, #T_bc0e6_row3_col2, #T_bc0e6_row4_col5, #T_bc0e6_row5_col4 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_bc0e6_row2_col5, #T_bc0e6_row5_col2 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_bc0e6_row2_col7, #T_bc0e6_row5_col10, #T_bc0e6_row7_col2, #T_bc0e6_row10_col5 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_bc0e6_row2_col8, #T_bc0e6_row8_col2 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_bc0e6_row2_col9, #T_bc0e6_row9_col2 {
#   background-color: #192b7c;
#   color: #f1f1f1;
# }
# #T_bc0e6_row2_col10, #T_bc0e6_row8_col11, #T_bc0e6_row10_col2, #T_bc0e6_row11_col8 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_bc0e6_row2_col11, #T_bc0e6_row8_col10, #T_bc0e6_row10_col8, #T_bc0e6_row11_col2 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_bc0e6_row3_col4, #T_bc0e6_row4_col3 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_bc0e6_row3_col7, #T_bc0e6_row7_col3 {
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_bc0e6_row3_col8, #T_bc0e6_row8_col3 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_bc0e6_row3_col9, #T_bc0e6_row9_col3 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_bc0e6_row3_col10, #T_bc0e6_row10_col3 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_bc0e6_row3_col11, #T_bc0e6_row11_col3 {
#   background-color: #65c3bf;
#   color: #000000;
# }
# #T_bc0e6_row4_col7, #T_bc0e6_row7_col4 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_bc0e6_row4_col8, #T_bc0e6_row8_col4 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_bc0e6_row4_col9, #T_bc0e6_row9_col4 {
#   background-color: #2168ad;
#   color: #f1f1f1;
# }
# #T_bc0e6_row4_col10, #T_bc0e6_row10_col4 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_bc0e6_row4_col11, #T_bc0e6_row11_col4 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_bc0e6_row5_col7, #T_bc0e6_row7_col5, #T_bc0e6_row7_col10, #T_bc0e6_row10_col7 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_bc0e6_row5_col8, #T_bc0e6_row8_col5 {
#   background-color: #234fa1;
#   color: #f1f1f1;
# }
# #T_bc0e6_row5_col9, #T_bc0e6_row9_col5 {
#   background-color: #2165ab;
#   color: #f1f1f1;
# }
# #T_bc0e6_row5_col11, #T_bc0e6_row11_col5 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_bc0e6_row6_col7, #T_bc0e6_row7_col6 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_bc0e6_row6_col8, #T_bc0e6_row8_col6 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_bc0e6_row6_col9, #T_bc0e6_row9_col6 {
#   background-color: #216aad;
#   color: #f1f1f1;
# }
# #T_bc0e6_row6_col10, #T_bc0e6_row10_col6 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_bc0e6_row7_col8, #T_bc0e6_row8_col7 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_bc0e6_row7_col9, #T_bc0e6_row9_col7 {
#   background-color: #35aac3;
#   color: #f1f1f1;
# }
# #T_bc0e6_row7_col11, #T_bc0e6_row11_col7 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_bc0e6_row8_col9, #T_bc0e6_row9_col8 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_bc0e6_row9_col10, #T_bc0e6_row10_col9 {
#   background-color: #87d0ba;
#   color: #000000;
# }
# #T_bc0e6_row9_col11, #T_bc0e6_row11_col9 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_bc0e6_row10_col11, #T_bc0e6_row11_col10 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# </style>
# <table id="T_bc0e6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc0e6_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_bc0e6_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_bc0e6_row0_col1" class="data row0 col1" >1.786800</td>
#       <td id="T_bc0e6_row0_col2" class="data row0 col2" >1.725800</td>
#       <td id="T_bc0e6_row0_col3" class="data row0 col3" >1.769000</td>
#       <td id="T_bc0e6_row0_col4" class="data row0 col4" >0.871900</td>
#       <td id="T_bc0e6_row0_col5" class="data row0 col5" >0.915000</td>
#       <td id="T_bc0e6_row0_col6" class="data row0 col6" >0.854000</td>
#       <td id="T_bc0e6_row0_col7" class="data row0 col7" >0.083300</td>
#       <td id="T_bc0e6_row0_col8" class="data row0 col8" >2.499900</td>
#       <td id="T_bc0e6_row0_col9" class="data row0 col9" >2.240100</td>
#       <td id="T_bc0e6_row0_col10" class="data row0 col10" >0.748800</td>
#       <td id="T_bc0e6_row0_col11" class="data row0 col11" >0.196600</td>
#     </tr>
#     <tr>
#       <th id="T_bc0e6_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_bc0e6_row1_col0" class="d
# <center><h3>orthologs_cytoglobin</h3></center>
# <style type="text/css">
# #T_c0005_row0_col0, #T_c0005_row1_col1, #T_c0005_row2_col2, #T_c0005_row2_col3, #T_c0005_row3_col2, #T_c0005_row3_col3, #T_c0005_row4_col4, #T_c0005_row4_col5, #T_c0005_row5_col4, #T_c0005_row5_col5, #T_c0005_row6_col6, #T_c0005_row7_col7, #T_c0005_row8_col8, #T_c0005_row9_col9, #T_c0005_row10_col10, #T_c0005_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_c0005_row0_col1, #T_c0005_row1_col0, #T_c0005_row8_col10, #T_c0005_row10_col8 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_c0005_row0_col2, #T_c0005_row0_col3, #T_c0005_row2_col0, #T_c0005_row3_col0 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_c0005_row0_col4, #T_c0005_row0_col5, #T_c0005_row1_col4, #T_c0005_row1_col5, #T_c0005_row2_col6, #T_c0005_row3_col6, #T_c0005_row4_col0, #T_c0005_row4_col1, #T_c0005_row5_col0, #T_c0005_row5_col1, #T_c0005_row6_col2, #T_c0005_row6_col3 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_c0005_row0_col6, #T_c0005_row2_col4, #T_c0005_row2_col5, #T_c0005_row3_col4, #T_c0005_row3_col5, #T_c0005_row4_col2, #T_c0005_row4_col3, #T_c0005_row5_col2, #T_c0005_row5_col3, #T_c0005_row5_col11, #T_c0005_row6_col0, #T_c0005_row11_col5 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_c0005_row0_col7, #T_c0005_row7_col0 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_c0005_row0_col8, #T_c0005_row8_col0 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_c0005_row0_col9, #T_c0005_row9_col0 {
#   background-color: #73c8bd;
#   color: #000000;
# }
# #T_c0005_row0_col10, #T_c0005_row10_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_c0005_row0_col11, #T_c0005_row11_col0 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_c0005_row1_col2, #T_c0005_row1_col3, #T_c0005_row2_col1, #T_c0005_row3_col1, #T_c0005_row4_col6, #T_c0005_row5_col6, #T_c0005_row6_col4, #T_c0005_row6_col5 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_c0005_row1_col6, #T_c0005_row6_col1 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# #T_c0005_row1_col7, #T_c0005_row1_col11, #T_c0005_row7_col1, #T_c0005_row7_col9, #T_c0005_row9_col7, #T_c0005_row11_col1 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_c0005_row1_col8, #T_c0005_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_c0005_row1_col9, #T_c0005_row9_col1 {
#   background-color: #24459c;
#   color: #f1f1f1;
# }
# #T_c0005_row1_col10, #T_c0005_row10_col1 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_c0005_row2_col7, #T_c0005_row3_col7, #T_c0005_row7_col2, #T_c0005_row7_col3 {
#   background-color: #71c8bd;
#   color: #000000;
# }
# #T_c0005_row2_col8, #T_c0005_row3_col8, #T_c0005_row8_col2, #T_c0005_row8_col3 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_c0005_row2_col9, #T_c0005_row3_col9, #T_c0005_row9_col2, #T_c0005_row9_col3 {
#   background-color: #24479d;
#   color: #f1f1f1;
# }
# #T_c0005_row2_col10, #T_c0005_row3_col10, #T_c0005_row10_col2, #T_c0005_row10_col3 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
# }
# #T_c0005_row2_col11, #T_c0005_row3_col11, #T_c0005_row9_col11, #T_c0005_row11_col2, #T_c0005_row11_col3, #T_c0005_row11_col9 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_c0005_row4_col7, #T_c0005_row4_col11, #T_c0005_row5_col7, #T_c0005_row7_col4, #T_c0005_row7_col5, #T_c0005_row11_col4 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_c0005_row4_col8, #T_c0005_row5_col8, #T_c0005_row8_col4, #T_c0005_row8_col5 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_c0005_row4_col9, #T_c0005_row5_col9, #T_c0005_row9_col4, #T_c0005_row9_col5 {
#   background-color: #2195c0;
#   color: #f1f1f1;
# }
# #T_c0005_row4_col10, #T_c0005_row5_col10, #T_c0005_row10_col4, #T_c0005_row10_col5 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_c0005_row6_col7, #T_c0005_row7_col6 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_c0005_row6_col8, #T_c0005_row8_col6 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_c0005_row6_col9, #T_c0005_row9_col6 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_c0005_row6_col10, #T_c0005_row10_col6 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_c0005_row6_col11, #T_c0005_row11_col6 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_c0005_row7_col8, #T_c0005_row8_col7 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_c0005_row7_col10, #T_c0005_row10_col7 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_c0005_row7_col11, #T_c0005_row11_col7 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_c0005_row8_col9, #T_c0005_row9_col8 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_c0005_row8_col11, #T_c0005_row11_col8 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_c0005_row9_col10, #T_c0005_row10_col9 {
#   background-color: #caeab4;
#   color: #000000;
# }
# #T_c0005_row10_col11, #T_c0005_row11_col10 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# </style>
# <table id="T_c0005_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0005_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_c0005_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_c0005_row0_col1" class="data row0 col1" >3.572300</td>
#       <td id="T_c0005_row0_col2" class="data row0 col2" >3.526700</td>
#       <td id="T_c0005_row0_col3" class="data row0 col3" >3.529400</td>
#       <td id="T_c0005_row0_col4" class="data row0 col4" >1.784900</td>
#       <td id="T_c0005_row0_col5" class="data row0 col5" >1.787500</td>
#       <td id="T_c0005_row0_col6" class="data row0 col6" >1.742100</td>
#       <td id="T_c0005_row0_col7" class="data row0 col7" >0.120400</td>
#       <td id="T_c0005_row0_col8" class="data row0 col8" >4.917700</td>
#       <td id="T_c0005_row0_col9" class="data row0 col9" >3.411000</td>
#       <td id="T_c0005_row0_col10" class="data row0 col10" >1.378100</td>
#       <td id="T_c0005_row0_col11" class="data row0 col11" >0.184500</td>
#     </tr>
#     <tr>
#       <th id="T_c0005_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_c0005_row1_col0" class="data row1 col0" >3.572300</td>
#       <td id="T_c0005_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c0005_row1_col2" class="data row1 col2" >0.060500</td>
#       <td id="T_c0005_row1_col3" class="data row1 col3" >0.061600</td>
#       <td id="T_c0005_row1_col4" class="data row1 col4" >1.787500</td>
#       <td id="T_c0005_row1_col5" class="data row1 col5" >1.784900</td>
#       <td id="T_c0005_row1_col6" class="data row1 col6" >1.831100</td>
#       <td id="T_c0005_row1_col7" class="data row1 col7" >3.483900</td>
#       <td id="T_c0005_row1_col8" class="data row1 col8" >8.486200</td>
#       <td id="T_c0005_row1_col9" class="data row1 col9" >6.974900</td>
#       <td id="T_c0005_row1_col10" class="data row1 col10" >4.947400</td>
#       <t
# <center><h3>orthologs_androglobin</h3></center>
# <style type="text/css">
# #T_42142_row0_col0, #T_42142_row1_col1, #T_42142_row2_col2, #T_42142_row3_col3, #T_42142_row4_col4, #T_42142_row5_col5, #T_42142_row6_col6, #T_42142_row7_col7, #T_42142_row8_col8, #T_42142_row9_col9, #T_42142_row10_col10, #T_42142_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_42142_row0_col1, #T_42142_row1_col0 {
#   background-color: #1e85ba;
#   color: #f1f1f1;
# }
# #T_42142_row0_col2, #T_42142_row2_col0, #T_42142_row4_col10, #T_42142_row10_col4 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_42142_row0_col3, #T_42142_row3_col0, #T_42142_row5_col10, #T_42142_row10_col5 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_42142_row0_col4, #T_42142_row1_col5, #T_42142_row2_col6, #T_42142_row3_col4, #T_42142_row4_col0, #T_42142_row4_col3, #T_42142_row5_col1, #T_42142_row6_col2 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_42142_row0_col5, #T_42142_row1_col4, #T_42142_row3_col6, #T_42142_row4_col1, #T_42142_row5_col0, #T_42142_row6_col3 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_42142_row0_col6, #T_42142_row0_col10, #T_42142_row2_col4, #T_42142_row3_col5, #T_42142_row4_col2, #T_42142_row5_col3, #T_42142_row6_col0, #T_42142_row10_col0 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_42142_row0_col7, #T_42142_row7_col0 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_42142_row0_col8, #T_42142_row1_col6, #T_42142_row6_col1, #T_42142_row7_col10, #T_42142_row8_col0, #T_42142_row10_col7 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_42142_row0_col9, #T_42142_row9_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_42142_row0_col11, #T_42142_row11_col0 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_42142_row1_col2, #T_42142_row2_col1, #T_42142_row5_col6, #T_42142_row6_col5 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_42142_row1_col3, #T_42142_row2_col3, #T_42142_row3_col1, #T_42142_row3_col2, #T_42142_row4_col5, #T_42142_row4_col6, #T_42142_row5_col4, #T_42142_row6_col4 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_42142_row1_col7, #T_42142_row6_col10, #T_42142_row7_col1, #T_42142_row10_col6 {
#   background-color: #1f7eb7;
#   color: #f1f1f1;
# }
# #T_42142_row1_col8, #T_42142_row8_col1 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_42142_row1_col9, #T_42142_row9_col1 {
#   background-color: #225aa6;
#   color: #f1f1f1;
# }
# #T_42142_row1_col10, #T_42142_row10_col1 {
#   background-color: #0a1e5c;
#   color: #f1f1f1;
# }
# #T_42142_row1_col11, #T_42142_row11_col1 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_42142_row2_col5, #T_42142_row5_col2, #T_42142_row5_col7, #T_42142_row7_col5 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_42142_row2_col7, #T_42142_row7_col2 {
#   background-color: #1f7ab5;
#   color: #f1f1f1;
# }
# #T_42142_row2_col8, #T_42142_row8_col2 {
#   background-color: #0d2163;
#   color: #f1f1f1;
# }
# #T_42142_row2_col9, #T_42142_row9_col2 {
#   background-color: #2356a4;
#   color: #f1f1f1;
# }
# #T_42142_row2_col10, #T_42142_row10_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_42142_row2_col11, #T_42142_row11_col2 {
#   background-color: #2094c0;
#   color: #f1f1f1;
# }
# #T_42142_row3_col7, #T_42142_row7_col3 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_42142_row3_col8, #T_42142_row8_col3 {
#   background-color: #0e2265;
#   color: #f1f1f1;
# }
# #T_42142_row3_col9, #T_42142_row9_col3 {
#   background-color: #2259a6;
#   color: #f1f1f1;
# }
# #T_42142_row3_col10, #T_42142_row10_col3 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_42142_row3_col11, #T_42142_row11_col3 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_42142_row4_col7, #T_42142_row7_col4 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_42142_row4_col8, #T_42142_row8_col4 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_42142_row4_col9, #T_42142_row9_col4 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_42142_row4_col11, #T_42142_row11_col4 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_42142_row5_col8, #T_42142_row8_col5 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_42142_row5_col9, #T_42142_row9_col5 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_42142_row5_col11, #T_42142_row9_col10, #T_42142_row10_col9, #T_42142_row11_col5 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_42142_row6_col7, #T_42142_row7_col6 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_42142_row6_col8, #T_42142_row8_col6 {
#   background-color: #1e88bc;
#   color: #f1f1f1;
# }
# #T_42142_row6_col9, #T_42142_row9_col6 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_42142_row6_col11, #T_42142_row11_col6 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_42142_row7_col8, #T_42142_row8_col7 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_42142_row7_col9, #T_42142_row9_col7 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_42142_row7_col11, #T_42142_row11_col7 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_42142_row8_col9, #T_42142_row9_col8 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_42142_row8_col10, #T_42142_row10_col8 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_42142_row8_col11, #T_42142_row11_col8 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_42142_row9_col11, #T_42142_row11_col9 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_42142_row10_col11, #T_42142_row11_col10 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# </style>
# <table id="T_42142_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42142_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_42142_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_42142_row0_col1" class="data row0 col1" >3.292500</td>
#       <td id="T_42142_row0_col2" class="data row0 col2" >3.348900</td>
#       <td id="T_42142_row0_col3" class="data row0 col3" >3.315300</td>
#       <td id="T_42142_row0_col4" class="data row0 col4" >1.663000</td>
#       <td id="T_42142_row0_col5" class="data row0 col5" >1.629500</td>
#       <td id="T_42142_row0_col6" class="data row0 col6" >1.685900</td>
#       <td id="T_42142_row0_col7" class="data row0 col7" >0.084300</td>
#       <td id="T_42142_row0_col8" class="data row0 col8" >1.608100</td>
#       <td id="T_42142_row0_col9" class="data row0 col9" >0.816500</td>
#       <td id="T_42142_row0_col10" class="data row0 col10" >1.676900</td>
#       <td id="T_42142_row0_col11" class="data row0 col11" >0.326500</td>
#     </tr>
#     <tr>
#       <th id="T_42142_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_42142_row1_col0" class="data row1 col0" >3.292500</td>
#       <td id="T_42142_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_42142_row1_col2" class="data row1 col2" >0.059300</td>
#       <td id="T_42142_row1_c
