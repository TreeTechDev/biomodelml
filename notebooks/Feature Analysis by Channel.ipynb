# %% [markdown]
# # Comparing channels
#
# - R: sequential
# - G: reverse complementary
# - B: mutation

# %%
import pandas
import os
import numpy
from scipy.stats import spearmanr
from IPython.core.display import display, HTML
from ete3 import Tree

# %%
def read_and_compare(dataset, channel="full"):
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Euclidean Distance from distance matrices

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.2576  0.9769  0.7896
# orthologs_myoglobin                           0.9044  1.0656  1.1520  0.3363
# orthologs_neuroglobin                         1.1514  2.1996  1.7168  0.7343
# orthologs_cytoglobin                          3.1095  2.7496  3.2111  1.5308
# orthologs_androglobin                         2.9601  6.0038  0.9328  1.0347
#
# index                        blue  red_green  red_blue  green_blue  gray_r  \
# dataset
# orthologs_hemoglobin_beta  0.4126     0.4849    0.1212      0.0856  0.2307
# orthologs_myoglobin        0.5559     0.3349    0.5562      1.0644  1.1463
# orthologs_neuroglobin      0.9246     0.7363    0.9245      2.1953  1.7038
# orthologs_cytoglobin       1.6787     1.5302    1.6698      2.7388  3.1773
# orthologs_androglobin      2.7933     2.4228    4.4080      4.3502  4.0998
#
# index                      gray_g   gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  1.0531   1.0589    1.1348     0.9446
# orthologs_myoglobin        1.3572   3.0733    1.9439     1.4614
# orthologs_neuroglobin      4.2191   4.1341    4.2177     3.3593
# orthologs_cytoglobin       7.8948   4.1154    7.5911     5.8818
# orthologs_androglobin      5.5033  10.0380   10.0831     7.8460

# %%
channels = ("full", "red", "green", "blue")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.2576  0.9769  0.7896
# orthologs_myoglobin                           0.9044  1.0656  1.1520  0.3363
# orthologs_neuroglobin                         1.1514  2.1996  1.7168  0.7343
# orthologs_cytoglobin                          3.1095  2.7496  3.2111  1.5308
# orthologs_androglobin                         2.9601  6.0038  0.9328  1.0347
#
# index                        blue
# dataset
# orthologs_hemoglobin_beta  0.4126
# orthologs_myoglobin        0.5559
# orthologs_neuroglobin      0.9246
# orthologs_cytoglobin       1.6787
# orthologs_androglobin      2.7933

# %%
channels = ("full", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Local with Smith–Waterman    full  gray_r  gray_g  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.2576  0.2307  1.0531
# orthologs_myoglobin                           0.9044  1.0656  1.1463  1.3572
# orthologs_neuroglobin                         1.1514  2.1996  1.7038  4.2191
# orthologs_cytoglobin                          3.1095  2.7496  3.1773  7.8948
# orthologs_androglobin                         2.9601  6.0038  4.0998  5.5033
#
# index                       gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta   1.0589    1.1348     0.9446
# orthologs_myoglobin         3.0733    1.9439     1.4614
# orthologs_neuroglobin       4.1341    4.2177     3.3593
# orthologs_cytoglobin        4.1154    7.5911     5.8818
# orthologs_androglobin      10.0380   10.0831     7.8460

# %%
channels = ("full", "red_green", "red_blue", "green_blue")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9085
# orthologs_myoglobin                              0.9196
# orthologs_neuroglobin                            1.8043
# orthologs_cytoglobin                             6.3417
# orthologs_androglobin                            8.2855
#
# index                      Local with Smith–Waterman    full  red_green  \
# dataset
# orthologs_hemoglobin_beta                     0.8937  0.2576     0.4849
# orthologs_myoglobin                           0.9044  1.0656     0.3349
# orthologs_neuroglobin                         1.1514  2.1996     0.7363
# orthologs_cytoglobin                          3.1095  2.7496     1.5302
# orthologs_androglobin                         2.9601  6.0038     2.4228
#
# index                      red_blue  green_blue
# dataset
# orthologs_hemoglobin_beta    0.1212      0.0856
# orthologs_myoglobin          0.5562      1.0644
# orthologs_neuroglobin        0.9245      2.1953
# orthologs_cytoglobin         1.6698      2.7388
# orthologs_androglobin        4.4080      4.3502

# %%
def read_and_correlate(dataset, channel="full"):
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_df = pandas.read_csv(f"{path}/Control with Clustal Omega.csv", index_col=0)
    for file in os.listdir(path):
        if file.endswith(".csv"):
            basename = ".".join(file.split(".")[0:-1])
            df = pandas.read_csv(f"{path}/{file}", index_col=0)
            result_dict[basename] = round(spearmanr(control_df.values.flatten(), df.values.flatten())[0], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Linear Correlation from distance matrices

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_correlate(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         1.0
# orthologs_myoglobin                               1.0
# orthologs_neuroglobin                             1.0
# orthologs_cytoglobin                              1.0
# orthologs_androglobin                             1.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.9999
# orthologs_myoglobin                              0.9999
# orthologs_neuroglobin                            0.9999
# orthologs_cytoglobin                             0.7775
# orthologs_androglobin                            0.9054
#
# index                      Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.9998  0.9921  0.9904  0.9964
# orthologs_myoglobin                           0.9998  0.9696  0.8616  0.9746
# orthologs_neuroglobin                         0.9992  0.9701  0.9299  0.9637
# orthologs_cytoglobin                          0.8623  0.7043  0.6461  0.5230
# orthologs_androglobin                         0.9769  0.5899  0.5633  0.5505
#
# index                        blue  red_green  red_blue  green_blue  gray_r  \
# dataset
# orthologs_hemoglobin_beta  0.9856     0.9952    0.9877      0.9919  0.9900
# orthologs_myoglobin        0.9659     0.9749    0.9659      0.9696  0.9947
# orthologs_neuroglobin      0.9343     0.9637    0.9351      0.9701  0.9906
# orthologs_cytoglobin       0.6785     0.5259    0.6591      0.7051  0.6028
# orthologs_androglobin      0.3791     0.5798    0.5779      0.5815  0.5778
#
# index                      gray_g  gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  0.9934  0.9856    0.9860     0.9890
# orthologs_myoglobin        0.9746  0.9659    0.9878     0.9846
# orthologs_neuroglobin      0.9637  0.9342    0.9679     0.9681
# orthologs_cytoglobin       0.5230  0.6706    0.6021     0.5608
# orthologs_androglobin      0.8322  0.4976    0.5870     0.7016

# %%
def read_and_tree_compare(dataset, channel="full"):
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_tree = Tree(f"{path}/Control with Clustal Omega.nw", format=1)
    for file in os.listdir(path):
        if file.endswith(".nw"):
            basename = ".".join(file.split(".")[0:-1])
            tree = Tree(f"{path}/{file}", format=1)
            result = control_tree.compare(tree, unrooted=True)
            result_dict[basename] = round(result["norm_rf"], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Robinson-foulds distance from generated Trees

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0000
# orthologs_cytoglobin                             0.6667
# orthologs_androglobin                            0.8333
#
# index                      Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                        0.0  0.0000  0.0833  0.0000
# orthologs_myoglobin                              0.0  0.1667  0.2500  0.2500
# orthologs_neuroglobin                            0.0  0.2500  0.5000  0.1667
# orthologs_cytoglobin                             0.5  0.8333  0.7500  0.9167
# orthologs_androglobin                            0.5  0.9167  0.9167  0.9167
#
# index                        blue  red_green  red_blue  green_blue  gray_r  \
# dataset
# orthologs_hemoglobin_beta  0.0000     0.0000    0.0000      0.0000  0.0833
# orthologs_myoglobin        0.1667     0.2500    0.1667      0.1667  0.0833
# orthologs_neuroglobin      0.3333     0.1667    0.3333      0.2500  0.1667
# orthologs_cytoglobin       1.0000     0.9167    0.9167      0.8333  0.9167
# orthologs_androglobin      0.9167     0.9167    0.9167      0.9167  0.9167
#
# index                      gray_g  gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  0.0000  0.0000    0.0000     0.0000
# orthologs_myoglobin        0.2500  0.1667    0.0833     0.0833
# orthologs_neuroglobin      0.1667  0.3333    0.2500     0.2500
# orthologs_cytoglobin       0.9167  1.0000    0.9167     0.9167
# orthologs_androglobin      0.9167  0.9167    0.9167     0.9167

# %%
def read_and_tree_compare_branches(dataset, channel="full"):
    result_dict = {}
    path = f"../data/trees/{channel}/{dataset}"
    control_tree = Tree(f"{path}/Control with Clustal Omega.nw", format=1)
    for file in os.listdir(path):
        if file.endswith(".nw"):
            basename = ".".join(file.split(".")[0:-1])
            tree = Tree(f"{path}/{file}", format=1)
            result = control_tree.compare(tree, unrooted=True)
            result_dict[basename] = 1.0 - round(result["source_edges_in_ref"], 4)
    result_df = pandas.DataFrame(result_dict, index=[dataset])
    result_df.rename(columns={"MultiScale Structural Similarity Index Measure": channel}, inplace=True)
    result_df.index.name = "dataset"
    return result_df

# %% [markdown]
# ## Compatibility branch score from generated Trees

# %%
channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
datasets = ["orthologs_hemoglobin_beta", "orthologs_myoglobin", "orthologs_neuroglobin", "orthologs_cytoglobin", "orthologs_androglobin"]
sum_dfs = []
for channel in channels:
    dfs = []
    for dataset in datasets:
        dfs.append(read_and_tree_compare_branches(dataset, channel))
    sum_dfs.append(pandas.concat(dfs))
pandas.concat(sum_dfs, axis=1).T.reset_index().drop_duplicates().set_index("index").T
# Out:
# index                      Control with Clustal Omega  \
# dataset
# orthologs_hemoglobin_beta                         0.0
# orthologs_myoglobin                               0.0
# orthologs_neuroglobin                             0.0
# orthologs_cytoglobin                              0.0
# orthologs_androglobin                             0.0
#
# index                      Global with Needleman-Wunsch  \
# dataset
# orthologs_hemoglobin_beta                        0.0000
# orthologs_myoglobin                              0.0000
# orthologs_neuroglobin                            0.0000
# orthologs_cytoglobin                             0.3077
# orthologs_androglobin                            0.3846
#
# index                      Local with Smith–Waterman    full     red   green  \
# dataset
# orthologs_hemoglobin_beta                     0.0000  0.0000  0.0385  0.0000
# orthologs_myoglobin                           0.0000  0.0769  0.1154  0.1154
# orthologs_neuroglobin                         0.0000  0.1154  0.2308  0.0769
# orthologs_cytoglobin                          0.2308  0.3846  0.3462  0.4231
# orthologs_androglobin                         0.2308  0.4231  0.4231  0.4231
#
# index                        blue  red_green  red_blue  green_blue  gray_r  \
# dataset
# orthologs_hemoglobin_beta  0.0000     0.0000    0.0000      0.0000  0.0385
# orthologs_myoglobin        0.0769     0.1154    0.0769      0.0769  0.0385
# orthologs_neuroglobin      0.1538     0.0769    0.1538      0.1154  0.0769
# orthologs_cytoglobin       0.4615     0.4231    0.4231      0.3846  0.4231
# orthologs_androglobin      0.4231     0.4231    0.4231      0.4231  0.4231
#
# index                      gray_g  gray_b  gray_max  gray_mean
# dataset
# orthologs_hemoglobin_beta  0.0000  0.0000    0.0000     0.0000
# orthologs_myoglobin        0.1154  0.0769    0.0385     0.0385
# orthologs_neuroglobin      0.0769  0.1538    0.1154     0.1154
# orthologs_cytoglobin       0.4231  0.4615    0.4231     0.4231
# orthologs_androglobin      0.4231  0.4231    0.4231     0.4231

# %%
def read_and_compare_channels(dataset):
    result_dict = {}
    dfs = {}
    channels = ("full", "red", "green", "blue", "red_green", "red_blue", "green_blue", "gray_r", "gray_g", "gray_b", "gray_max", "gray_mean")
    for channel in channels:
        result_dict[channel] = {}
        path = f"../data/trees/{channel}/{dataset}"
        dfs[channel] = pandas.read_csv(f"{path}/MultiScale Structural Similarity Index Measure.csv", index_col=0)
    for channel in channels:
        control_df = dfs[channel]
        for c, df in dfs.items():
            result_dict[channel][c] = round(numpy.sqrt(numpy.sum((control_df.values - df.values)**2)), 4)
    result_df = pandas.DataFrame.from_dict(result_dict, orient='index')
    result_df.index.name = "dataset"
    return result_df.style.background_gradient(axis=None, vmin=result_df.min().min(), vmax=result_df.max().max(), cmap="YlGnBu")

# %% [markdown]
# ## Features Euclidean distance from distance matrices

# %%
for dataset in datasets:
    display(HTML(f"<center><h3>{dataset}</h3></center>"))
    display(read_and_compare_channels(dataset))
# Out:
# <center><h3>orthologs_hemoglobin_beta</h3></center>
# <style type="text/css">
# #T_705ad_row0_col0, #T_705ad_row1_col1, #T_705ad_row2_col2, #T_705ad_row3_col3, #T_705ad_row4_col4, #T_705ad_row5_col5, #T_705ad_row6_col6, #T_705ad_row7_col7, #T_705ad_row8_col8, #T_705ad_row9_col9, #T_705ad_row10_col10, #T_705ad_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_705ad_row0_col1, #T_705ad_row1_col0 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_705ad_row0_col2, #T_705ad_row2_col0, #T_705ad_row5_col11, #T_705ad_row11_col5 {
#   background-color: #44b7c4;
#   color: #f1f1f1;
# }
# #T_705ad_row0_col3, #T_705ad_row3_col0 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_705ad_row0_col4, #T_705ad_row2_col6, #T_705ad_row4_col0, #T_705ad_row6_col2 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_705ad_row0_col5, #T_705ad_row3_col6, #T_705ad_row5_col0, #T_705ad_row6_col3 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_705ad_row0_col6, #T_705ad_row2_col4, #T_705ad_row3_col5, #T_705ad_row4_col2, #T_705ad_row5_col3, #T_705ad_row6_col0 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_705ad_row0_col7, #T_705ad_row7_col0 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_705ad_row0_col8, #T_705ad_row8_col0 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_705ad_row0_col9, #T_705ad_row9_col0 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_705ad_row0_col10, #T_705ad_row10_col0 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_705ad_row0_col11, #T_705ad_row11_col0 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_705ad_row1_col2, #T_705ad_row2_col1 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_705ad_row1_col3, #T_705ad_row2_col7, #T_705ad_row3_col1, #T_705ad_row7_col2 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_705ad_row1_col4, #T_705ad_row4_col1 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_705ad_row1_col5, #T_705ad_row5_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_705ad_row1_col6, #T_705ad_row6_col1 {
#   background-color: #61c2bf;
#   color: #000000;
# }
# #T_705ad_row1_col7, #T_705ad_row7_col1 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_705ad_row1_col8, #T_705ad_row8_col1 {
#   background-color: #11246b;
#   color: #f1f1f1;
# }
# #T_705ad_row1_col9, #T_705ad_row9_col1 {
#   background-color: #102369;
#   color: #f1f1f1;
# }
# #T_705ad_row1_col10, #T_705ad_row10_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_705ad_row1_col11, #T_705ad_row11_col1 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_705ad_row2_col3, #T_705ad_row3_col2, #T_705ad_row4_col5, #T_705ad_row5_col4 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_705ad_row2_col5, #T_705ad_row5_col2 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_705ad_row2_col8, #T_705ad_row2_col9, #T_705ad_row8_col2, #T_705ad_row9_col2 {
#   background-color: #253494;
#   color: #f1f1f1;
# }
# #T_705ad_row2_col10, #T_705ad_row10_col2 {
#   background-color: #1c2d81;
#   color: #f1f1f1;
# }
# #T_705ad_row2_col11, #T_705ad_row11_col2 {
#   background-color: #24459c;
#   color: #f1f1f1;
# }
# #T_705ad_row3_col4, #T_705ad_row4_col3, #T_705ad_row9_col10, #T_705ad_row10_col9 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_705ad_row3_col7, #T_705ad_row7_col3, #T_705ad_row10_col11, #T_705ad_row11_col10 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_705ad_row3_col8, #T_705ad_row3_col9, #T_705ad_row8_col3, #T_705ad_row9_col3 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_705ad_row3_col10, #T_705ad_row4_col8, #T_705ad_row4_col9, #T_705ad_row8_col4, #T_705ad_row9_col4, #T_705ad_row10_col3 {
#   background-color: #2166ac;
#   color: #f1f1f1;
# }
# #T_705ad_row3_col11, #T_705ad_row11_col3 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_705ad_row4_col6, #T_705ad_row6_col4 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_705ad_row4_col7, #T_705ad_row7_col4 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_705ad_row4_col10, #T_705ad_row10_col4 {
#   background-color: #2258a5;
#   color: #f1f1f1;
# }
# #T_705ad_row4_col11, #T_705ad_row11_col4 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_705ad_row5_col6, #T_705ad_row6_col5 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_705ad_row5_col7, #T_705ad_row7_col5 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_705ad_row5_col8, #T_705ad_row5_col9, #T_705ad_row8_col5, #T_705ad_row9_col5 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_705ad_row5_col10, #T_705ad_row10_col5 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_705ad_row6_col7, #T_705ad_row7_col6 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_705ad_row6_col8, #T_705ad_row8_col6 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_705ad_row6_col9, #T_705ad_row9_col6 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_705ad_row6_col10, #T_705ad_row10_col6 {
#   background-color: #2ea3c2;
#   color: #f1f1f1;
# }
# #T_705ad_row6_col11, #T_705ad_row11_col6 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_705ad_row7_col8, #T_705ad_row8_col7 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_705ad_row7_col9, #T_705ad_row9_col7 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_705ad_row7_col10, #T_705ad_row10_col7 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_705ad_row7_col11, #T_705ad_row11_col7 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_705ad_row8_col9, #T_705ad_row9_col8 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_705ad_row8_col10, #T_705ad_row10_col8 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_705ad_row8_col11, #T_705ad_row11_col8 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_705ad_row9_col11, #T_705ad_row11_col9 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# </style>
# <table id="T_705ad_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_705ad_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_705ad_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_705ad_row0_col1" class="data row0 col1" >1.224800</td>
#       <td id="T_705ad_row0_col2" class="data row0 col2" >1.037200</td>
#       <td id="T_705ad_row0_col3" class="data row0 col3" >0.656900</td>
#       <td id="T_705ad_row0_col4" class="data row0 col4" >0.731200</td>
#       <td id="T_705ad_row0_col5" class="data row0 col5" >0.350800</td>
#       <td id="T_705ad_row0_col6" class="data row0 col6" >0.306400</td>
#       <td id="T_705ad_row0_col7" class="data row0 col7" >0.470800</td>
#       <td id="T_705ad_row0_col8" class="data row0 col8" >0.802200</td>
#       <td id="T_705ad_row0_col9" class="data row0 col9" >0.806700</td>
#       <td id="T_705ad_row0_col10" class="data row0 col10" >0.882600</td>
#       <td id="T_705ad_row0_col11" class="data row0 col11" >0.692600</td>
#     </tr>
#     <tr>
#       <th id="T_705ad_level0_row1" class="row_heading level0 row1" >
# <center><h3>orthologs_myoglobin</h3></center>
# <style type="text/css">
# #T_425eb_row0_col0, #T_425eb_row1_col1, #T_425eb_row2_col2, #T_425eb_row3_col3, #T_425eb_row4_col4, #T_425eb_row5_col5, #T_425eb_row6_col6, #T_425eb_row7_col7, #T_425eb_row8_col8, #T_425eb_row9_col9, #T_425eb_row10_col10, #T_425eb_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_425eb_row0_col1, #T_425eb_row1_col0, #T_425eb_row5_col9, #T_425eb_row9_col5 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_425eb_row0_col2, #T_425eb_row2_col0 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_425eb_row0_col3, #T_425eb_row3_col0 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_425eb_row0_col4, #T_425eb_row1_col7, #T_425eb_row2_col6, #T_425eb_row4_col0, #T_425eb_row6_col2, #T_425eb_row7_col1 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_425eb_row0_col5, #T_425eb_row3_col6, #T_425eb_row5_col0, #T_425eb_row6_col3 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_425eb_row0_col6, #T_425eb_row2_col4, #T_425eb_row3_col5, #T_425eb_row4_col2, #T_425eb_row5_col3, #T_425eb_row6_col0 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_425eb_row0_col7, #T_425eb_row1_col4, #T_425eb_row4_col1, #T_425eb_row7_col0 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_425eb_row0_col8, #T_425eb_row8_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_425eb_row0_col9, #T_425eb_row1_col5, #T_425eb_row5_col1, #T_425eb_row9_col0 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_425eb_row0_col10, #T_425eb_row7_col8, #T_425eb_row8_col7, #T_425eb_row10_col0 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_425eb_row0_col11, #T_425eb_row11_col0 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_425eb_row1_col2, #T_425eb_row2_col1, #T_425eb_row5_col7, #T_425eb_row7_col5 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_425eb_row1_col3, #T_425eb_row3_col1 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_425eb_row1_col6, #T_425eb_row6_col1 {
#   background-color: #6bc6be;
#   color: #000000;
# }
# #T_425eb_row1_col8, #T_425eb_row8_col1 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_425eb_row1_col9, #T_425eb_row9_col1 {
#   background-color: #102369;
#   color: #f1f1f1;
# }
# #T_425eb_row1_col10, #T_425eb_row10_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_425eb_row1_col11, #T_425eb_row11_col1 {
#   background-color: #233390;
#   color: #f1f1f1;
# }
# #T_425eb_row2_col3, #T_425eb_row3_col2, #T_425eb_row4_col5, #T_425eb_row4_col6, #T_425eb_row5_col4, #T_425eb_row6_col4, #T_425eb_row8_col9, #T_425eb_row9_col8 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_425eb_row2_col5, #T_425eb_row5_col2 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_425eb_row2_col7, #T_425eb_row7_col2 {
#   background-color: #b9e4b5;
#   color: #000000;
# }
# #T_425eb_row2_col8, #T_425eb_row8_col2 {
#   background-color: #216aad;
#   color: #f1f1f1;
# }
# #T_425eb_row2_col9, #T_425eb_row9_col2 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_425eb_row2_col10, #T_425eb_row10_col2 {
#   background-color: #172978;
#   color: #f1f1f1;
# }
# #T_425eb_row2_col11, #T_425eb_row11_col2 {
#   background-color: #23499e;
#   color: #f1f1f1;
# }
# #T_425eb_row3_col4, #T_425eb_row4_col3 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_425eb_row3_col7, #T_425eb_row6_col7, #T_425eb_row7_col3, #T_425eb_row7_col6 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_425eb_row3_col8, #T_425eb_row8_col3 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_425eb_row3_col9, #T_425eb_row9_col3 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_425eb_row3_col10, #T_425eb_row10_col3 {
#   background-color: #2166ac;
#   color: #f1f1f1;
# }
# #T_425eb_row3_col11, #T_425eb_row11_col3 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_425eb_row4_col7, #T_425eb_row7_col4, #T_425eb_row8_col11, #T_425eb_row11_col8 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_425eb_row4_col8, #T_425eb_row8_col4 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_425eb_row4_col9, #T_425eb_row9_col4 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_425eb_row4_col10, #T_425eb_row10_col4 {
#   background-color: #2350a1;
#   color: #f1f1f1;
# }
# #T_425eb_row4_col11, #T_425eb_row11_col4 {
#   background-color: #1f7db6;
#   color: #f1f1f1;
# }
# #T_425eb_row5_col6, #T_425eb_row6_col5 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_425eb_row5_col8, #T_425eb_row8_col5 {
#   background-color: #7acbbc;
#   color: #000000;
# }
# #T_425eb_row5_col10, #T_425eb_row10_col5 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_425eb_row5_col11, #T_425eb_row11_col5 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_425eb_row6_col8, #T_425eb_row8_col6 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_425eb_row6_col9, #T_425eb_row9_col6 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_425eb_row6_col10, #T_425eb_row10_col6 {
#   background-color: #299dc1;
#   color: #f1f1f1;
# }
# #T_425eb_row6_col11, #T_425eb_row11_col6 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_425eb_row7_col9, #T_425eb_row9_col7 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_425eb_row7_col10, #T_425eb_row10_col7 {
#   background-color: #1e85ba;
#   color: #f1f1f1;
# }
# #T_425eb_row7_col11, #T_425eb_row11_col7 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_425eb_row8_col10, #T_425eb_row10_col8 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_425eb_row9_col10, #T_425eb_row10_col9 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_425eb_row9_col11, #T_425eb_row11_col9 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_425eb_row10_col11, #T_425eb_row11_col10 {
#   background-color: #eef8b3;
#   color: #000000;
# }
# </style>
# <table id="T_425eb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_425eb_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_425eb_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_425eb_row0_col1" class="data row0 col1" >1.385300</td>
#       <td id="T_425eb_row0_col2" class="data row0 col2" >1.211900</td>
#       <td id="T_425eb_row0_col3" class="data row0 col3" >0.703500</td>
#       <td id="T_425eb_row0_col4" class="data row0 col4" >0.864100</td>
#       <td id="T_425eb_row0_col5" class="data row0 col5" >0.355800</td>
#       <td id="T_425eb_row0_col6" class="data row0 col6" >0.348000</td>
#       <td id="T_425eb_row0_col7" class="data row0 col7" >0.524900</td>
#       <td id="T_425eb_row0_col8" class="data row0 col8" >0.613300</td>
#       <td id="T_425eb_row0_col9" class="data row0 col9" >1.026300</td>
#       <td id="T_425eb_row0_col10" class="data row0 col10" >1.117700</td>
#       <td id="T_425eb_row0_col11" class="data row0 col11" >0.819500</td>
#     </tr>
#     <tr>
#       <th id="T_425eb_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_425eb_row1_col0" class="d
# <center><h3>orthologs_neuroglobin</h3></center>
# <style type="text/css">
# #T_d1558_row0_col0, #T_d1558_row1_col1, #T_d1558_row2_col2, #T_d1558_row3_col3, #T_d1558_row4_col4, #T_d1558_row5_col5, #T_d1558_row6_col6, #T_d1558_row7_col7, #T_d1558_row8_col8, #T_d1558_row9_col9, #T_d1558_row10_col10, #T_d1558_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_d1558_row0_col1, #T_d1558_row1_col0 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_d1558_row0_col2, #T_d1558_row2_col0 {
#   background-color: #3eb3c4;
#   color: #f1f1f1;
# }
# #T_d1558_row0_col3, #T_d1558_row3_col0 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_d1558_row0_col4, #T_d1558_row2_col6, #T_d1558_row4_col0, #T_d1558_row6_col2 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_d1558_row0_col5, #T_d1558_row3_col6, #T_d1558_row5_col0, #T_d1558_row6_col3 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_d1558_row0_col6, #T_d1558_row2_col4, #T_d1558_row3_col5, #T_d1558_row4_col2, #T_d1558_row5_col3, #T_d1558_row6_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_d1558_row0_col7, #T_d1558_row7_col0 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_d1558_row0_col8, #T_d1558_row8_col0 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_d1558_row0_col9, #T_d1558_row9_col0 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_d1558_row0_col10, #T_d1558_row10_col0 {
#   background-color: #75c9bd;
#   color: #000000;
# }
# #T_d1558_row0_col11, #T_d1558_row1_col3, #T_d1558_row3_col1, #T_d1558_row11_col0 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_d1558_row1_col2, #T_d1558_row2_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_d1558_row1_col4, #T_d1558_row4_col1 {
#   background-color: #c4e8b4;
#   color: #000000;
# }
# #T_d1558_row1_col5, #T_d1558_row5_col1 {
#   background-color: #63c3bf;
#   color: #000000;
# }
# #T_d1558_row1_col6, #T_d1558_row6_col1 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_d1558_row1_col7, #T_d1558_row7_col1 {
#   background-color: #71c8bd;
#   color: #000000;
# }
# #T_d1558_row1_col8, #T_d1558_row8_col1 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_d1558_row1_col9, #T_d1558_row9_col1 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_d1558_row1_col10, #T_d1558_row10_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_d1558_row1_col11, #T_d1558_row11_col1 {
#   background-color: #243392;
#   color: #f1f1f1;
# }
# #T_d1558_row2_col3, #T_d1558_row3_col2, #T_d1558_row4_col5, #T_d1558_row5_col4 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_d1558_row2_col5, #T_d1558_row5_col2 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_d1558_row2_col7, #T_d1558_row7_col2 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_d1558_row2_col8, #T_d1558_row8_col2 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_d1558_row2_col9, #T_d1558_row9_col2 {
#   background-color: #253494;
#   color: #f1f1f1;
# }
# #T_d1558_row2_col10, #T_d1558_row10_col2 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_d1558_row2_col11, #T_d1558_row11_col2 {
#   background-color: #2352a3;
#   color: #f1f1f1;
# }
# #T_d1558_row3_col4, #T_d1558_row4_col3 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_d1558_row3_col7, #T_d1558_row7_col3 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_d1558_row3_col8, #T_d1558_row4_col11, #T_d1558_row8_col3, #T_d1558_row11_col4 {
#   background-color: #1d91c0;
#   color: #f1f1f1;
# }
# #T_d1558_row3_col9, #T_d1558_row9_col3 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_d1558_row3_col10, #T_d1558_row10_col3 {
#   background-color: #2166ac;
#   color: #f1f1f1;
# }
# #T_d1558_row3_col11, #T_d1558_row11_col3 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_d1558_row4_col6, #T_d1558_row6_col4 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_d1558_row4_col7, #T_d1558_row7_col4 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_d1558_row4_col8, #T_d1558_row8_col4 {
#   background-color: #1e8bbd;
#   color: #f1f1f1;
# }
# #T_d1558_row4_col9, #T_d1558_row9_col4 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_d1558_row4_col10, #T_d1558_row10_col4 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_d1558_row5_col6, #T_d1558_row6_col5 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_d1558_row5_col7, #T_d1558_row7_col5 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_d1558_row5_col8, #T_d1558_row8_col5 {
#   background-color: #53bdc1;
#   color: #000000;
# }
# #T_d1558_row5_col9, #T_d1558_row9_col5 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_d1558_row5_col10, #T_d1558_row10_col5 {
#   background-color: #2da2c2;
#   color: #f1f1f1;
# }
# #T_d1558_row5_col11, #T_d1558_row11_col5 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_d1558_row6_col7, #T_d1558_row7_col6 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_d1558_row6_col8, #T_d1558_row8_col6 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_d1558_row6_col9, #T_d1558_row9_col6 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_d1558_row6_col10, #T_d1558_row10_col6 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_d1558_row6_col11, #T_d1558_row11_col6 {
#   background-color: #61c2bf;
#   color: #000000;
# }
# #T_d1558_row7_col8, #T_d1558_row8_col7 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
# }
# #T_d1558_row7_col9, #T_d1558_row9_col7 {
#   background-color: #2ea3c2;
#   color: #f1f1f1;
# }
# #T_d1558_row7_col10, #T_d1558_row10_col7 {
#   background-color: #259ac1;
#   color: #f1f1f1;
# }
# #T_d1558_row7_col11, #T_d1558_row11_col7 {
#   background-color: #50bbc2;
#   color: #000000;
# }
# #T_d1558_row8_col9, #T_d1558_row9_col8 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_d1558_row8_col10, #T_d1558_row10_col8 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_d1558_row8_col11, #T_d1558_row11_col8 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_d1558_row9_col10, #T_d1558_row10_col9 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_d1558_row9_col11, #T_d1558_row11_col9 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_d1558_row10_col11, #T_d1558_row11_col10 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# </style>
# <table id="T_d1558_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1558_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_d1558_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_d1558_row0_col1" class="data row0 col1" >3.195900</td>
#       <td id="T_d1558_row0_col2" class="data row0 col2" >2.698600</td>
#       <td id="T_d1558_row0_col3" class="data row0 col3" >1.769000</td>
#       <td id="T_d1558_row0_col4" class="data row0 col4" >1.844800</td>
#       <td id="T_d1558_row0_col5" class="data row0 col5" >0.915000</td>
#       <td id="T_d1558_row0_col6" class="data row0 col6" >0.854000</td>
#       <td id="T_d1558_row0_col7" class="data row0 col7" >1.052700</td>
#       <td id="T_d1558_row
# <center><h3>orthologs_cytoglobin</h3></center>
# <style type="text/css">
# #T_15449_row0_col0, #T_15449_row1_col1, #T_15449_row2_col2, #T_15449_row3_col3, #T_15449_row4_col4, #T_15449_row5_col5, #T_15449_row6_col6, #T_15449_row7_col7, #T_15449_row8_col8, #T_15449_row9_col9, #T_15449_row10_col10, #T_15449_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_15449_row0_col1, #T_15449_row1_col0 {
#   background-color: #1d8ebf;
#   color: #f1f1f1;
# }
# #T_15449_row0_col2, #T_15449_row2_col0 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_15449_row0_col3, #T_15449_row3_col0 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_15449_row0_col4, #T_15449_row2_col6, #T_15449_row2_col7, #T_15449_row4_col0, #T_15449_row6_col2, #T_15449_row7_col2 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_15449_row0_col5, #T_15449_row3_col6, #T_15449_row3_col7, #T_15449_row5_col0, #T_15449_row6_col3, #T_15449_row7_col3 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_15449_row0_col6, #T_15449_row0_col7, #T_15449_row2_col4, #T_15449_row3_col5, #T_15449_row4_col2, #T_15449_row5_col3, #T_15449_row6_col0, #T_15449_row7_col0 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_15449_row0_col8, #T_15449_row8_col0 {
#   background-color: #95d5b9;
#   color: #000000;
# }
# #T_15449_row0_col9, #T_15449_row9_col0 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_15449_row0_col10, #T_15449_row10_col0 {
#   background-color: #80cebb;
#   color: #000000;
# }
# #T_15449_row0_col11, #T_15449_row1_col3, #T_15449_row3_col1, #T_15449_row11_col0 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_15449_row1_col2, #T_15449_row2_col1 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_15449_row1_col4, #T_15449_row4_col1 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_15449_row1_col5, #T_15449_row5_col1, #T_15449_row6_col11, #T_15449_row7_col11, #T_15449_row11_col6, #T_15449_row11_col7 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_15449_row1_col6, #T_15449_row6_col1 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_15449_row1_col7, #T_15449_row5_col11, #T_15449_row7_col1, #T_15449_row11_col5 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_15449_row1_col8, #T_15449_row8_col1 {
#   background-color: #0f2367;
#   color: #f1f1f1;
# }
# #T_15449_row1_col9, #T_15449_row9_col1 {
#   background-color: #0d2161;
#   color: #f1f1f1;
# }
# #T_15449_row1_col10, #T_15449_row10_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_15449_row1_col11, #T_15449_row11_col1 {
#   background-color: #21308b;
#   color: #f1f1f1;
# }
# #T_15449_row2_col3, #T_15449_row3_col2, #T_15449_row4_col5, #T_15449_row4_col7, #T_15449_row5_col4, #T_15449_row7_col4 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_15449_row2_col5, #T_15449_row5_col2 {
#   background-color: #8cd2ba;
#   color: #000000;
# }
# #T_15449_row2_col8, #T_15449_row8_col2 {
#   background-color: #253494;
#   color: #f1f1f1;
# }
# #T_15449_row2_col9, #T_15449_row9_col2 {
#   background-color: #22328f;
#   color: #f1f1f1;
# }
# #T_15449_row2_col10, #T_15449_row10_col2 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_15449_row2_col11, #T_15449_row11_col2 {
#   background-color: #234da0;
#   color: #f1f1f1;
# }
# #T_15449_row3_col4, #T_15449_row4_col3, #T_15449_row5_col7, #T_15449_row7_col5 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_15449_row3_col8, #T_15449_row8_col3 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_15449_row3_col9, #T_15449_row9_col3 {
#   background-color: #216daf;
#   color: #f1f1f1;
# }
# #T_15449_row3_col10, #T_15449_row10_col3 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_15449_row3_col11, #T_15449_row11_col3 {
#   background-color: #1d90c0;
#   color: #f1f1f1;
# }
# #T_15449_row4_col6, #T_15449_row6_col4 {
#   background-color: #ddf2b2;
#   color: #000000;
# }
# #T_15449_row4_col8, #T_15449_row8_col4 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_15449_row4_col9, #T_15449_row9_col4 {
#   background-color: #2070b0;
#   color: #f1f1f1;
# }
# #T_15449_row4_col10, #T_15449_row10_col4 {
#   background-color: #2166ac;
#   color: #f1f1f1;
# }
# #T_15449_row4_col11, #T_15449_row11_col4 {
#   background-color: #1f93c0;
#   color: #f1f1f1;
# }
# #T_15449_row5_col6, #T_15449_row6_col5 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_15449_row5_col8, #T_15449_row8_col5 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_15449_row5_col9, #T_15449_row7_col9, #T_15449_row9_col5, #T_15449_row9_col7 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_15449_row5_col10, #T_15449_row10_col5 {
#   background-color: #31a5c2;
#   color: #f1f1f1;
# }
# #T_15449_row6_col7, #T_15449_row7_col6, #T_15449_row9_col10, #T_15449_row10_col9 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_15449_row6_col8, #T_15449_row7_col8, #T_15449_row8_col6, #T_15449_row8_col7 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_15449_row6_col9, #T_15449_row9_col6 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_15449_row6_col10, #T_15449_row7_col10, #T_15449_row10_col6, #T_15449_row10_col7 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_15449_row8_col9, #T_15449_row9_col8 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_15449_row8_col10, #T_15449_row9_col11, #T_15449_row10_col8, #T_15449_row11_col9 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_15449_row8_col11, #T_15449_row11_col8 {
#   background-color: #f1faba;
#   color: #000000;
# }
# #T_15449_row10_col11, #T_15449_row11_col10 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# </style>
# <table id="T_15449_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15449_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_15449_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_15449_row0_col1" class="data row0 col1" >6.086400</td>
#       <td id="T_15449_row0_col2" class="data row0 col2" >5.188000</td>
#       <td id="T_15449_row0_col3" class="data row0 col3" >3.529400</td>
#       <td id="T_15449_row0_col4" class="data row0 col4" >3.448500</td>
#       <td id="T_15449_row0_col5" class="data row0 col5" >1.787500</td>
#       <td id="T_15449_row0_col6" class="data row0 col6" >1.742100</td>
#       <td id="T_15449_row0_col7" class="data row0 col7" >1.758100</td>
#       <td id="T_15449_row0_col8" class="data row0 col8" >3.273700</td>
#       <td id="T_15449_row0_col9" class="data row0 col9" >3.385800</td>
#       <td id="T_15449_row0_col10" class="data row0 col10" >3.600200</td>
#       <td id="T_15449_row0_col11" class="data row0 col11" >2.548700</td>
#     </tr>
#     <tr>
#       <th id="T_15449_level0_row1" class="row_heading level0 row1" >red</th>
#       <td id="T_15449_row1_col0" class="data row1 col0" >6.086400</td>
#       <td id="T_15449_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_15449_row1_col2" class="data row1 col2" >0.900400</td>
#       <td id="T_15449_row1_c
# <center><h3>orthologs_androglobin</h3></center>
# <style type="text/css">
# #T_083ce_row0_col0, #T_083ce_row1_col1, #T_083ce_row2_col2, #T_083ce_row3_col3, #T_083ce_row4_col4, #T_083ce_row5_col5, #T_083ce_row6_col6, #T_083ce_row7_col7, #T_083ce_row8_col8, #T_083ce_row9_col9, #T_083ce_row10_col10, #T_083ce_row11_col11 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_083ce_row0_col1, #T_083ce_row1_col0 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_083ce_row0_col2, #T_083ce_row2_col0 {
#   background-color: #3db2c4;
#   color: #f1f1f1;
# }
# #T_083ce_row0_col3, #T_083ce_row3_col0 {
#   background-color: #a0dab8;
#   color: #000000;
# }
# #T_083ce_row0_col4, #T_083ce_row2_col6, #T_083ce_row4_col0, #T_083ce_row6_col2 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_083ce_row0_col5, #T_083ce_row3_col6, #T_083ce_row5_col0, #T_083ce_row6_col3 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_083ce_row0_col6, #T_083ce_row2_col4, #T_083ce_row3_col5, #T_083ce_row4_col2, #T_083ce_row5_col3, #T_083ce_row6_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_083ce_row0_col7, #T_083ce_row7_col0 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_083ce_row0_col8, #T_083ce_row8_col0 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_083ce_row0_col9, #T_083ce_row9_col0 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_083ce_row0_col10, #T_083ce_row10_col0 {
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_083ce_row0_col11, #T_083ce_row11_col0 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_083ce_row1_col2, #T_083ce_row2_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_083ce_row1_col3, #T_083ce_row3_col1 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_083ce_row1_col4, #T_083ce_row4_col1 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_083ce_row1_col5, #T_083ce_row5_col1 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_083ce_row1_col6, #T_083ce_row6_col1, #T_083ce_row8_col10, #T_083ce_row10_col8 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# #T_083ce_row1_col7, #T_083ce_row7_col1 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_083ce_row1_col8, #T_083ce_row8_col1 {
#   background-color: #2ea3c2;
#   color: #f1f1f1;
# }
# #T_083ce_row1_col9, #T_083ce_row9_col1 {
#   background-color: #091e5a;
#   color: #f1f1f1;
# }
# #T_083ce_row1_col10, #T_083ce_row10_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_083ce_row1_col11, #T_083ce_row11_col1 {
#   background-color: #2351a2;
#   color: #f1f1f1;
# }
# #T_083ce_row2_col3, #T_083ce_row3_col2, #T_083ce_row4_col5, #T_083ce_row5_col4 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_083ce_row2_col5, #T_083ce_row5_col2 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_083ce_row2_col7, #T_083ce_row7_col2 {
#   background-color: #9cd8b8;
#   color: #000000;
# }
# #T_083ce_row2_col8, #T_083ce_row8_col2 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_083ce_row2_col9, #T_083ce_row9_col2 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
# }
# #T_083ce_row2_col10, #T_083ce_row10_col2 {
#   background-color: #1e2e85;
#   color: #f1f1f1;
# }
# #T_083ce_row2_col11, #T_083ce_row11_col2 {
#   background-color: #2076b3;
#   color: #f1f1f1;
# }
# #T_083ce_row3_col4, #T_083ce_row4_col3 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_083ce_row3_col7, #T_083ce_row7_col3 {
#   background-color: #e9f7b1;
#   color: #000000;
# }
# #T_083ce_row3_col8, #T_083ce_row8_col3 {
#   background-color: #b7e3b6;
#   color: #000000;
# }
# #T_083ce_row3_col9, #T_083ce_row9_col3 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_083ce_row3_col10, #T_083ce_row10_col3 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_083ce_row3_col11, #T_083ce_row11_col3 {
#   background-color: #44b7c4;
#   color: #f1f1f1;
# }
# #T_083ce_row4_col6, #T_083ce_row6_col4 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_083ce_row4_col7, #T_083ce_row7_col4 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_083ce_row4_col8, #T_083ce_row8_col4 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_083ce_row4_col9, #T_083ce_row9_col4 {
#   background-color: #2262aa;
#   color: #f1f1f1;
# }
# #T_083ce_row4_col10, #T_083ce_row10_col4 {
#   background-color: #2260a9;
#   color: #f1f1f1;
# }
# #T_083ce_row4_col11, #T_083ce_row11_col4 {
#   background-color: #37acc3;
#   color: #f1f1f1;
# }
# #T_083ce_row5_col6, #T_083ce_row6_col5, #T_083ce_row9_col10, #T_083ce_row10_col9 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_083ce_row5_col7, #T_083ce_row7_col5 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_083ce_row5_col8, #T_083ce_row8_col5 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_083ce_row5_col9, #T_083ce_row9_col5 {
#   background-color: #35aac3;
#   color: #f1f1f1;
# }
# #T_083ce_row5_col10, #T_083ce_row6_col9, #T_083ce_row9_col6, #T_083ce_row10_col5 {
#   background-color: #33a7c2;
#   color: #f1f1f1;
# }
# #T_083ce_row5_col11, #T_083ce_row11_col5 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_083ce_row6_col7, #T_083ce_row7_col6 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_083ce_row6_col8, #T_083ce_row8_col6 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_083ce_row6_col10, #T_083ce_row10_col6 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_083ce_row6_col11, #T_083ce_row11_col6 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_083ce_row7_col8, #T_083ce_row8_col7 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_083ce_row7_col9, #T_083ce_row9_col7 {
#   background-color: #2b9fc2;
#   color: #f1f1f1;
# }
# #T_083ce_row7_col10, #T_083ce_row10_col7 {
#   background-color: #2a9ec1;
#   color: #f1f1f1;
# }
# #T_083ce_row7_col11, #T_083ce_row11_col7 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_083ce_row8_col9, #T_083ce_row9_col8 {
#   background-color: #5dc0c0;
#   color: #000000;
# }
# #T_083ce_row8_col11, #T_083ce_row11_col8 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_083ce_row9_col11, #T_083ce_row11_col9 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_083ce_row10_col11, #T_083ce_row11_col10 {
#   background-color: #d1edb3;
#   color: #000000;
# }
# </style>
# <table id="T_083ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >full</th>
#       <th class="col_heading level0 col1" >red</th>
#       <th class="col_heading level0 col2" >green</th>
#       <th class="col_heading level0 col3" >blue</th>
#       <th class="col_heading level0 col4" >red_green</th>
#       <th class="col_heading level0 col5" >red_blue</th>
#       <th class="col_heading level0 col6" >green_blue</th>
#       <th class="col_heading level0 col7" >gray_r</th>
#       <th class="col_heading level0 col8" >gray_g</th>
#       <th class="col_heading level0 col9" >gray_b</th>
#       <th class="col_heading level0 col10" >gray_max</th>
#       <th class="col_heading level0 col11" >gray_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_083ce_level0_row0" class="row_heading level0 row0" >full</th>
#       <td id="T_083ce_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_083ce_row0_col1" class="data row0 col1" >6.365400</td>
#       <td id="T_083ce_row0_col2" class="data row0 col2" >5.354600</td>
#       <td id="T_083ce_row0_col3" class="data row0 col3" >3.315300</td>
#       <td id="T_083ce_row0_col4" class="data row0 col4" >3.675100</td>
#       <td id="T_083ce_row0_col5" class="data row0 col5" >1.629500</td>
#       <td id="T_083ce_row0_col6" class="data row0 col6" >1.685900</td>
#       <td id="T_083ce_row0_col7" class="data row0 col7" >1.950100</td>
#       <td id="T_083ce_row0_col8" class="data row0 col8" >0.793700</td>
